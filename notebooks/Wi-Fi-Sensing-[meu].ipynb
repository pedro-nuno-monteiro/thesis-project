# %% [markdown]
# ### Wi-Fi Sensing

# %% [markdown]
# #### Initial Setup

# %%
# pandas for data manipulation
# re for regular expressions
import re

# pyplot for plotting
import matplotlib.pyplot as plt

# numpy for numerical operations
import numpy as np
import pandas as pd

# seaborn for advanced plotting
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, make_scorer

# sklearn for machine learning
from sklearn.model_selection import GridSearchCV, train_test_split

# other .py files
from utils.csv_import import get_csv_files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 21
#      18 from sklearn.model_selection import GridSearchCV, train_test_split
#      20 # other .py files
# ---> 21 from utils.csv_import import get_csv_files
#
# ModuleNotFoundError: No module named 'utils'

# %%
# Retrieve CSV files
path: str = (
    "C:\\Users\\pedro\\OneDrive - Universidade de Coimbra\\Ambiente de Trabalho"
    "\\tese\\thesis-project\\data"
    "\\CSI DATA RENAMED [alterado]"
)

# path: str = "C:\\Users\\Oscar\\Documents\\GitHub\\thesis-project_isac\\CSI DATA RENAMED [alterado]"

FileMap = dict[str, dict[str, str]]

csv_loureiro: FileMap = {}
csv_diana: FileMap = {}
csv_afinar: FileMap = {}

csv_loureiro, csv_diana, csv_afinar = get_csv_files(path)

# Initialize variables
subcarriers: list[int] = list(range(51))
esps_id: list[int] = [1, 2, 3, 4]

# %% [markdown]
# #### *Def functions*

# %% [markdown]
# ##### Print functions info

# %%
def print_useful_info(file: FileMap) -> None:
    # Print information about the files dictionaries
    print("Número de ficheiros recolhidos: ", len(file))

    # avoid StopIteration if dict is empty
    esp_count = len(next(iter(file.values()))) if file else 0
    print("ESPs por cenário:", esp_count)

    # Print all scenarios names
    print("\nTodos os cenários:", sorted(file.keys()))

    # Count scenarios by letter prefix
    scenario_prefixes: dict[str, int] = {}
    for scenario in file:
        prefix = scenario[0]
        scenario_prefixes[prefix] = scenario_prefixes.get(prefix, 0) + 1

    print("\nN.º cenários/posição:")
    for prefix, count in sorted(scenario_prefixes.items()):
        print(f"Posição {prefix}: {count} cenários")

    print("---\n")

# %% [markdown]
# ##### Cálculo módulo (magnitude) ((posição x esp) (array de arrays))

# %%
# função que processo o arquivo CSV completo
# # e extrai a info da coluna do CSI
# # converte em números complexos
# # calcula a magnitude (2.º passo)
# #
# e faz ainda uma 1a limpeza
# # remove 2 primeiras subportadoras
# # remove colunas a zero
# # aplica FFT shift

# da tese
# # Vector size verification
# # Subcarrier layout and magnitude computation

csi_map = dict[str, dict[str, np.ndarray]]


def process_csi(file: str) -> np.ndarray:
    df = pd.read_csv(file, header=None)
    csi_col = df.iloc[:, 26]

    total_sc: int = 128
    valid_csi: list[list[float]] = []

    for entry in csi_col:
        match = re.search(r"\[(.*?)\]", str(entry))
        if not match:
            continue
        nums = [float(n) for n in re.findall(r"-?\d+", match.group(1))]
        if len(nums) == total_sc:
            valid_csi.append(nums)

    valid_csi = np.array(valid_csi)
    complex_csi = valid_csi[:, ::2] + 1j * valid_csi[:, 1::2]
    magnitudes = np.abs(complex_csi)

    # Limpeza: remover 2 primeiras subportadoras e colunas todas-zero
    magnitudes = magnitudes[:, 2:]
    magnitudes = magnitudes[:, ~np.all(magnitudes == 0, axis=0)]
    magnitudes = np.fft.fftshift(magnitudes, axes=1)

    return magnitudes


# cria o dict magnitudes
# itera sobre cada posicao da grelha
# # para cada posicao, itera sobre cada esp_id e path
# # devolve o dict magnitudes preenchido
def process_magnitudes(file: FileMap) -> dict[str, dict[str, np.ndarray]]:
    magnitudes: dict[str, dict[str, np.ndarray]] = {}

    for posicao in file:
        magnitudes[posicao] = {}

        # dict com "esp_id" e "path"
        esps = file[posicao]

        for esp_id, ficheiro in esps.items():
            magnitudes[posicao][esp_id] = process_csi(ficheiro)

    return magnitudes


# o dict magnitudes fica
# posicao1
# # esp1
# # # array de arrays (cada leitura é um array)
# # ...
# # esp4
# # # array de arrays (cada leitura é um array)

# %% [markdown]
# ##### Cálculo da média

# %%
# cálculo das médias das subportadoras

# função que extrai valores de determiada subportadora
# # recolhe apenas uma fracção dos valores (1/6 * nº leituras)
# # e devolve um dicionário com os resultados
# # # dict esp: array de valores
def extrai_valores_sc(
    magnitudes_dict: csi_map, posicao: str, subcarrier: int, frac: float
) -> dict[str, np.ndarray]:
    resultados: dict[str, np.ndarray] = {}
    n: int
    for esp, matriz in magnitudes_dict[posicao].items():
        n = int(matriz.shape[0] * frac)
        resultados[esp] = matriz[:n, subcarrier]
    return resultados


# função que calcula a média dos valores extraídos na função de cima
# retorna um dict com
# # esp: média
# Nota: np.mean retorna um np.floating; para satisfazer o tipo dict[str, float]
# convertemos explicitamente para float()
def calcular_media_sc(subportadora_dict: dict[str, np.ndarray]) -> dict[str, float]:
    return {esp: float(np.mean(valores)) for esp, valores in subportadora_dict.items()}


# função que calcula a média para cada subportadora
# # para cada sc
# # extrai os (n * frac) primeiros valores de cada esp
# # calcula a sua média
# # # devolve um dict com
# # # subcarrier: {esp_y: média}
def calcular_medias_para_varias_subportadoras(
    magnitudes_dict: csi_map, posicao: str, subcarrier_indices: list[int], frac: float
) -> dict[int, dict[str, float]]:
    medias_por_subc: dict[int, dict[str, float]] = {}
    for sc in subcarrier_indices:
        valores = extrai_valores_sc(magnitudes_dict, posicao, sc, frac)
        medias = calcular_media_sc(valores)
        medias_por_subc[sc] = medias
    return medias_por_subc

# %% [markdown]
# ##### Criar dataset "dados" (sc x posição) (array)

# %%
# para cada posição
# # ver o tamanho de cada (auto definido em cima)
# # e para cada subportadora
# # # e para cada esp
# # # # extrair o vetor correto
# # # # guardar no dicionário

dados_map = dict[int, dict[str, np.ndarray]]


def criar_dataset(
    posicoes: list[str], tamanhos: dict[str, int], magnitudes: csi_map
) -> dados_map:
    dados: dados_map = {}
    dados = {sc: {} for sc in subcarriers}

    for posicao in posicoes:
        tamanho = tamanhos[posicao]
        for sc in subcarriers:
            for esp_id in esps_id:
                # acede ao array de arrays
                matriz = magnitudes[posicao][f"esp_{esp_id}"]
                # extrai o vetor coluna
                # com (linhas/leituras = tamanho)
                # com (coluna = subc)
                vetor = matriz[:tamanho, sc]
                # print("nº linhas = ", matriz.shape[0], " e tamanho = ", tamanho)
                chave = f"{posicao}_esp_{esp_id}"
                dados[sc][chave] = vetor

    return dados

# %% [markdown]
# ##### Normalizar dados

# %%
# Função para normalizar
# a função recebe o dicionário de vetores e o dicionário de médias
# e devolve o dicionário de vetores normalizados
# cada vetor é normalizado subtraindo a média e dividindo pela média
def normalizar_vetores(
    posicoes: list[str],
    dados: dados_map,
    medias: dict[int, dict[str, float]],
) -> dados_map:
    normalizados: dados_map = {}
    normalizados = {sc: {} for sc in subcarriers}

    for sc in subcarriers:
        for posicao in posicoes:
            for esp_id in esps_id:
                chave = f"{posicao}_esp_{esp_id}"
                vetor = dados[sc][chave]

                esp = f"esp_{esp_id}"
                media = medias[sc][esp]

                normalizados[sc][chave] = (vetor - media) / media
    return normalizados


# Função para normalizar dados a afinar
def normalizar_vetores_afinar(
    posicoes_afinar: list[str],
    vetores: dados_map,
    medias: dict[int, dict[str, float]],
) -> dados_map:
    normalizados: dados_map = {}
    normalizados = {sc: {} for sc in subcarriers}

    for sc in subcarriers:
        for posicao in posicoes_afinar:
            for esp_id in esps_id:
                chave = f"{posicao}_esp_{esp_id}"
                vetor = vetores[sc][chave]

                esp = f"esp_{esp_id}"
                media = medias[sc][esp]

                normalizados[sc][chave] = (vetor - media) / media
    return normalizados

# %% [markdown]
# ##### Cálculo mean, std, máx

# %%
# função para calcular a média em janelas sobrepostas
def media_grupos_overlap(
    vetor: np.ndarray, tamanho_janela: int, step: int
) -> np.ndarray:
    medias: list[float] = []
    for i in range(0, len(vetor) - tamanho_janela + 1, step):
        janela = vetor[i : i + tamanho_janela]
        medias.append(float(np.mean(janela)))
    return np.array(medias)


# função para calcular o desvio padrão em janelas sobrepostas
def std_grupos_overlap(vetor: np.ndarray, tamanho_janela: int, step: int) -> np.ndarray:
    desvios: list[float] = []
    for i in range(0, len(vetor) - tamanho_janela + 1, step):
        janela = vetor[i : i + tamanho_janela]
        desvios.append(float(np.std(janela)))
    return np.array(desvios)


# função para calcular o máximo em janelas sobrepostas,
# evitando repetições dos últimos 3 máximos escolhidos
def max_grupos_overlap(vetor: np.ndarray, tamanho_janela: int, step: int) -> np.ndarray:
    maximos: list[float] = []
    for i in range(0, len(vetor) - tamanho_janela + 1, step):
        janela = vetor[i : i + tamanho_janela]
        candidatos = np.sort(np.unique(janela))[::-1]  # do maior para o menor

        # Exclui os 3 últimos valores
        ultimos = set(maximos[-3:])

        escolhido = None
        for val in candidatos:
            if val not in ultimos:
                escolhido = val
                break

        # Se todos os valores estão nos últimos 3, aceita o maior mesmo assim
        if escolhido is None:
            escolhido = candidatos[0]

        maximos.append(escolhido)

    return np.array(maximos)


def media_fixed(vetor: np.ndarray, tamanho_janela: int, w: int) -> np.ndarray:
    step = (len(vetor) - tamanho_janela) // (w - 1)
    return media_grupos_overlap(vetor, tamanho_janela, step)[:w]


def std_fixed(vetor: np.ndarray, tamanho_janela: int, w: int) -> np.ndarray:
    step = (len(vetor) - tamanho_janela) // (w - 1)
    return std_grupos_overlap(vetor, tamanho_janela, step)[:w]


def max_fixed(vetor: np.ndarray, tamanho_janela: int, w: int) -> np.ndarray:
    step = (len(vetor) - tamanho_janela) // (w - 1)
    return max_grupos_overlap(vetor, tamanho_janela, step)[:w]

# %% [markdown]
# #### *Pre Processing*

# %%
print_useful_info(csv_loureiro)
print_useful_info(csv_diana)
print_useful_info(csv_afinar)
# Out:
# Número de ficheiros recolhidos:  45
# ESPs por cenário: 4
#
# Todos os cenários: ['a00', 'a01', 'a02', 'a09', 'a10', 'a11', 'b00', 'b01', 'b02', 'b03', 'b04', 'b05', 'b06', 'b07', 'b08', 'b09', 'b10', 'b11', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10', 'c11', 'd01', 'd02', 'd03', 'd04', 'd05', 'd06', 'd07', 'd08', 'd09', 'd10', 'd11', 'e04', 'e05', 'e06', 'vazio_1', 'vazio_2']
#
# N.º cenários/posição:
# Posição a: 6 cenários
# Posição b: 12 cenários
# Posição c: 11 cenários
# Posição d: 11 cenários
# Posição e: 3 cenários
# Posição v: 2 cenários
# ---
#
# Número de ficheiros recolhidos:  45
# ESPs por cenário: 4
#
# Todos os cenários: ['a00', 'a01', 'a02', 'a09', 'a10', 'a11', 'b00', 'b01', 'b02', 'b03', 'b04', 'b05', 'b06', 'b07', 'b08', 'b09', 'b10', 'b11', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10', 'c11', 'd01', 'd02', 'd03', 'd04', 'd05', 'd06', 'd07', 'd08', 'd09', 'd10', 'd11', 'e04', 'e05', 'e06', 'vazio_1', 'vazio_2']
#
# N.º cenários/posição:
# Posição a: 6 cenários
# Posição b: 12 cenários
# Posição c: 11 cenários
# Posição d: 11 cenários
# Posição e: 3 cenários
# Posição v: 2 cenários
# ---
#
# Número de ficheiros recolhidos:  4
# ESPs por cenário: 4
#
# Todos os cenários: ['com_1', 'com_2', 'sem_1', 'sem_2']
#
# N.º cenários/posição:
# Posição c: 2 cenários
# Posição s: 2 cenários
# ---

# %% [markdown]
# Módulo

# %%
magnitudes_loureiro: csi_map = {}
magnitudes_diana: csi_map = {}
magnitudes_afinadas: csi_map = {}

magnitudes_loureiro = process_magnitudes(csv_loureiro)
magnitudes_diana = process_magnitudes(csv_diana)
magnitudes_afinadas = process_magnitudes(csv_afinar)

# %% [markdown]
# Média

# %%
# Posição: c06
#   esp: (nº leituras, nº subportadoras)
#   esp1: (76, 51) # 76 é matriz.shape[0]
#   esp2: (71, 51)
#   esp3: (79, 51)
#   esp4: (99, 51)

# posição para retirar normalizações - escolha ARBITRÁRIA (explorar outras opções?)
posicao: str = "c06"

# fração dos valores a considerar - porquê este valor?
frac: float = 1 / 6

# para a posição c06
# # para a subcarrier_x
# # # esp1: média
# # # esp2: média
# # # esp3: média
# # # esp4: média
medias_c06: dict[int, dict[str, float]] = {}
medias_c06 = calcular_medias_para_varias_subportadoras(
    magnitudes_loureiro, posicao, subcarriers, frac
)

# %% [markdown]
# Dataset "dados"

# %%
# Parâmetros

# tamanhos fixos selecionados para quando
# se fizer o "step" ficar número certo de amostras
#
# sem pessoa tem mais dados
N = 90
M = 350
O = 60
A = 292
I = 200

tamanhos_loureiro: dict[str, int] = {}
tamanhos_diana: dict[str, int] = {}
tamanhos_afinar: dict[str, int] = {}

tamanhos = {
    "vazio_1": M,
    "vazio_2": M,
    "a00": N,
    "c05": N,
    "a01": N,
    "c06": N,
    "a09": N,
    "c07": N,
    "a10": N,
    "c08": N,
    "a11": N,
    "c09": N,
    "b00": N,
    "c10": N,
    "b01": N,
    "c11": N,
    "b02": N,
    "d01": N,
    "b03": N,
    "d02": N,
    "b04": N,
    "d03": N,
    "b05": N,
    "d04": N,
    "b06": N,
    "d05": N,
    "b07": N,
    "d06": N,
    "b08": N,
    "d07": N,
    "b09": N,
    "d08": N,
    "b10": N,
    "d09": N,
    "b11": N,
    "d10": N,
    "c01": N,
    "d11": N,
    "c02": N,
    "e04": N,
    "c03": N,
    "e05": N,
    "c04": N,
    "e06": N,
}

tamanhos_diana = {
    "vazio_1": M,
    "vazio_2": M,
    "a00": O,
    "c05": O,
    "a01": O,
    "c06": O,
    "a09": O,
    "c07": O,
    "a10": O,
    "c08": O,
    "a11": O,
    "c09": O,
    "b00": O,
    "c10": O,
    "b01": O,
    "c11": O,
    "b02": O,
    "d01": O,
    "b03": O,
    "d02": O,
    "b04": O,
    "d03": O,
    "b05": O,
    "d04": O,
    "b06": O,
    "d05": O,
    "b07": O,
    "d06": O,
    "b08": O,
    "d07": O,
    "b09": O,
    "d08": O,
    "b10": O,
    "d09": O,
    "b11": O,
    "d10": O,
    "c01": O,
    "d11": O,
    "c02": O,
    "e04": O,
    "c03": O,
    "e05": O,
    "c04": O,
    "e06": O,
}

tamanhos_afinar = {
    "com_1": A,
    "sem_1": A,
    "com_2": I,
    "sem_2": I,
}

posicoes: list[str] = []
posicoes_afinar: list[str] = []

# do Miguel não há a02
posicoes = [
    "vazio_1",
    "vazio_2",
    "a00",
    "a01",
    "a09",
    "a10",
    "a11",
    "b00",
    "b01",
    "b02",
    "b03",
    "b04",
    "b05",
    "b06",
    "b07",
    "b08",
    "b09",
    "b10",
    "b11",
    "c01",
    "c02",
    "c03",
    "c04",
    "c05",
    "c06",
    "c07",
    "c08",
    "c09",
    "c10",
    "c11",
    "d01",
    "d02",
    "d03",
    "d04",
    "d05",
    "d06",
    "d07",
    "d08",
    "d09",
    "d10",
    "d11",
    "e04",
    "e05",
    "e06",
]

posicoes_afinar = ["sem_1", "sem_2", "com_1", "com_2"]

# %%
for sc in subcarriers:
    print(f"Subportadora {sc}:")
    for posicao in posicoes:
        for esp_id in esps_id:
            chave = f"{posicao}_esp_{esp_id}"
            tamanho_vetor = magnitudes_loureiro[posicao][f"esp_{esp_id}"].shape[0]
            esperado = tamanhos[posicao]
            print(
                f"  Verificando {chave}: tamanho vetor = {tamanho_vetor}, esperado = {esperado}"
            )
# Out:
# Subportadora 0:
#   Verificando vazio_1_esp_1: tamanho vetor = 22436, esperado = 350
#   Verificando vazio_1_esp_2: tamanho vetor = 17604, esperado = 350
#   Verificando vazio_1_esp_3: tamanho vetor = 21384, esperado = 350
#   Verificando vazio_1_esp_4: tamanho vetor = 23485, esperado = 350
#   Verificando vazio_2_esp_1: tamanho vetor = 149, esperado = 350
#   Verificando vazio_2_esp_2: tamanho vetor = 238, esperado = 350
#   Verificando vazio_2_esp_3: tamanho vetor = 177, esperado = 350
#   Verificando vazio_2_esp_4: tamanho vetor = 249, esperado = 350
#   Verificando a00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a00_esp_2: tamanho vetor = 118, esperado = 90
#   Verificando a00_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando a00_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando a01_esp_1: tamanho vetor = 41, esperado = 90
#   Verificando a01_esp_2: tamanho vetor = 42, esperado = 90
#   Verificando a01_esp_3: tamanho vetor = 54, esperado = 90
#   Verificando a01_esp_4: tamanho vetor = 74, esperado = 90
#   Verificando a09_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a09_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando a09_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando a09_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a10_esp_1: tamanho vetor = 129, esperado = 90
#   Verificando a10_esp_2: tamanho vetor = 90, esperado = 90
#   Verificando a10_esp_3: tamanho vetor = 81, esperado = 90
#   Verificando a10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a11_esp_1: tamanho vetor = 116, esperado = 90
#   Verificando a11_esp_2: tamanho vetor = 108, esperado = 90
#   Verificando a11_esp_3: tamanho vetor = 117, esperado = 90
#   Verificando a11_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b00_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b00_esp_3: tamanho vetor = 131, esperado = 90
#   Verificando b00_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b01_esp_1: tamanho vetor = 110, esperado = 90
#   Verificando b01_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b01_esp_3: tamanho vetor = 99, esperado = 90
#   Verificando b01_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b02_esp_1: tamanho vetor = 128, esperado = 90
#   Verificando b02_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b02_esp_3: tamanho vetor = 154, esperado = 90
#   Verificando b02_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b03_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b03_esp_2: tamanho vetor = 120, esperado = 90
#   Verificando b03_esp_3: tamanho vetor = 109, esperado = 90
#   Verificando b03_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando b04_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando b04_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando b04_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b05_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b05_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando b05_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando b05_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b06_esp_1: tamanho vetor = 101, esperado = 90
#   Verificando b06_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando b06_esp_3: tamanho vetor = 105, esperado = 90
#   Verificando b06_esp_4: tamanho vetor = 143, esperado = 90
#   Verificando b07_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b07_esp_2: tamanho vetor = 112, esperado = 90
#   Verificando b07_esp_3: tamanho vetor = 94, esperado = 90
#   Verificando b07_esp_4: tamanho vetor = 109, esperado = 90
#   Verificando b08_esp_1: tamanho vetor = 85, esperado = 90
#   Verificando b08_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b08_esp_3: tamanho vetor = 111, esperado = 90
#   Verificando b08_esp_4: tamanho vetor = 118, esperado = 90
#   Verificando b09_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b09_esp_2: tamanho vetor = 113, esperado = 90
#   Verificando b09_esp_3: tamanho vetor = 103, esperado = 90
#   Verificando b09_esp_4: tamanho vetor = 110, esperado = 90
#   Verificando b10_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando b10_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b10_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando b10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando b11_esp_1: tamanho vetor = 81, esperado = 90
#   Verificando b11_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b11_esp_3: tamanho vetor = 100, esperado = 90
#   Verificando b11_esp_4: tamanho vetor = 111, esperado = 90
#   Verificando c01_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando c01_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando c01_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando c01_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando c02_esp_1: tamanho vetor = 137, esperado = 90
#   Verificando c02_esp_2: tamanho vetor = 153, esperado = 90
#   Verificando c02_esp_3: tamanho vetor = 167, esperado = 90
#   Verificando c02_esp_4: tamanho vetor = 144, esperado = 90
#   Verificando c03_esp_1: tamanho vetor = 149, esperado = 90
#   Verificando c03_esp_2: tamanho vetor = 148, esperado = 90
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
#   Verificando c05_esp_2: tamanho vetor = 164, esperado = 90
#   Verificando c05_esp_3: tamanho vetor = 156, esperado = 90
#   Verificando c05_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando c06_esp_1: tamanho vetor = 76, esperado = 90
#   Verificando c06_esp_2: tamanho vetor = 71, esperado = 90
#   Verificando c06_esp_3: tamanho vetor = 79, esperado = 90
#   Verificando c06_esp_4: tamanho vetor = 99, esperado = 90
#   Verificando c07_esp_1: tamanho vetor = 170, esperado = 90
#   Verificando c07_esp_2: tamanho vetor = 126, esperado = 90
#   Verificando c07_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c07_esp_4: tamanho vetor = 183, esperado = 90
#   Verificando c08_esp_1: tamanho vetor = 162, esperado = 90
#   Verificando c08_esp_2: tamanho vetor = 141, esperado = 90
#   Verificando c08_esp_3: tamanho vetor = 149, esperado = 90
#   Verificando c08_esp_4: tamanho vetor = 174, esperado = 90
#   Verificando c09_esp_1: tamanho vetor = 159, esperado = 90
#   Verificando c09_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando c09_esp_3: tamanho vetor = 164, esperado = 90
#   Verificando c09_esp_4: tamanho vetor = 180, esperado = 90
#   Verificando c10_esp_1: tamanho vetor = 160, esperado = 90
#   Verificando c10_esp_2: tamanho vetor = 146, esperado = 90
#   Verificando c10_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c10_esp_4: tamanho vetor = 171, esperado = 90
#   Verificando c11_esp_1: tamanho vetor = 177, esperado = 90
#   Verificando c11_esp_2: tamanho vetor = 160, esperado = 90
#   Verificando c11_esp_3: tamanho vetor = 174, esperado = 90
#   Verificando c11_esp_4: tamanho vetor = 197, esperado = 90
#   Verificando d01_esp_1: tamanho vetor = 169, esperado = 90
#   Verificando d01_esp_2: tamanho vetor = 128, esperado = 90
#   Verificando d01_esp_3: tamanho vetor = 141, esperado = 90
#   Verificando d01_esp_4: tamanho vetor = 151, esperado = 90
#   Verificando d02_esp_1: tamanho vetor = 97, esperado = 90
#   Verificando d02_esp_2: tamanho vetor = 65, esperado = 90
#   Verificando d02_esp_3: tamanho vetor = 116, esperado = 90
#   Verificando d02_esp_4: tamanho vetor = 125, esperado = 90
#   Verificando d03_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando d03_esp_2: tamanho vetor = 109, esperado = 90
#   Verificando d03_esp_3: tamanho vetor = 104, esperado = 90
#   Verificando d03_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando d04_esp_1: tamanho vetor = 118, esperado = 90
#   Verificando d04_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando d04_esp_3: tamanho vetor = 169, esperado = 90
#   Verificando d04_esp_4: tamanho vetor = 158, esperado = 90
#   Verificando d05_esp_1: tamanho vetor = 89, esperado = 90
#   Verificando d05_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando d05_esp_3: tamanho vetor = 129, esperado = 90
#   Verificando d05_esp_4: tamanho vetor = 124, esperado = 90
#   Verificando d06_esp_1: tamanho vetor = 105, esperado = 90
#   Verificando d06_esp_2: tamanho vetor = 129, esperado = 90
#   Verificando d06_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando d06_esp_4: tamanho vetor = 149, esperado = 90
#   Verificando d07_esp_1: tamanho vetor = 107, esperado = 90
#   Verificando d07_esp_2: tamanho vetor = 117, esperado = 90
#   Verificando d07_esp_3: tamanho vetor = 159, esperado = 90
#   Verificando d07_esp_4: tamanho vetor = 135, esperado = 90
#   Verificando d08_esp_1: tamanho vetor = 166, esperado = 90
#   Verificando d08_esp_2: tamanho vetor = 115, esperado = 90
#   Verificando d08_esp_3: tamanho vetor = 130, esperado = 90
#   Verificando d08_esp_4: tamanho vetor = 165, esperado = 90
#   Verificando d09_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_2: tamanho vetor = 116, esperado = 90
#   Verificando d09_esp_3: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando d10_esp_1: tamanho vetor = 134, esperado = 90
#   Verificando d10_esp_2: tamanho vetor = 139, esperado = 90
#   Verificando d10_esp_3: tamanho vetor = 119, esperado = 90
#   Verificando d10_esp_4: tamanho vetor = 114, esperado = 90
#   Verificando d11_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando d11_esp_2: tamanho vetor = 110, esperado = 90
#   Verificando d11_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando d11_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando e04_esp_1: tamanho vetor = 130, esperado = 90
#   Verificando e04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando e04_esp_3: tamanho vetor = 127, esperado = 90
#   Verificando e04_esp_4: tamanho vetor = 130, esperado = 90
#   Verificando e05_esp_1: tamanho vetor = 121, esperado = 90
#   Verificando e05_esp_2: tamanho vetor = 105, esperado = 90
#   Verificando e05_esp_3: tamanho vetor = 123, esperado = 90
#   Verificando e05_esp_4: tamanho vetor = 119, esperado = 90
#   Verificando e06_esp_1: tamanho vetor = 143, esperado = 90
#   Verificando e06_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando e06_esp_3: tamanho vetor = 135, esperado = 90
#   Verificando e06_esp_4: tamanho vetor = 138, esperado = 90
# Subportadora 1:
#   Verificando vazio_1_esp_1: tamanho vetor = 22436, esperado = 350
#   Verificando vazio_1_esp_2: tamanho vetor = 17604, esperado = 350
#   Verificando vazio_1_esp_3: tamanho vetor = 21384, esperado = 350
#   Verificando vazio_1_esp_4: tamanho vetor = 23485, esperado = 350
#   Verificando vazio_2_esp_1: tamanho vetor = 149, esperado = 350
#   Verificando vazio_2_esp_2: tamanho vetor = 238, esperado = 350
#   Verificando vazio_2_esp_3: tamanho vetor = 177, esperado = 350
#   Verificando vazio_2_esp_4: tamanho vetor = 249, esperado = 350
#   Verificando a00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a00_esp_2: tamanho vetor = 118, esperado = 90
#   Verificando a00_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando a00_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando a01_esp_1: tamanho vetor = 41, esperado = 90
#   Verificando a01_esp_2: tamanho vetor = 42, esperado = 90
#   Verificando a01_esp_3: tamanho vetor = 54, esperado = 90
#   Verificando a01_esp_4: tamanho vetor = 74, esperado = 90
#   Verificando a09_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a09_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando a09_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando a09_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a10_esp_1: tamanho vetor = 129, esperado = 90
#   Verificando a10_esp_2: tamanho vetor = 90, esperado = 90
#   Verificando a10_esp_3: tamanho vetor = 81, esperado = 90
#   Verificando a10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a11_esp_1: tamanho vetor = 116, esperado = 90
#   Verificando a11_esp_2: tamanho vetor = 108, esperado = 90
#   Verificando a11_esp_3: tamanho vetor = 117, esperado = 90
#   Verificando a11_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b00_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b00_esp_3: tamanho vetor = 131, esperado = 90
#   Verificando b00_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b01_esp_1: tamanho vetor = 110, esperado = 90
#   Verificando b01_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b01_esp_3: tamanho vetor = 99, esperado = 90
#   Verificando b01_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b02_esp_1: tamanho vetor = 128, esperado = 90
#   Verificando b02_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b02_esp_3: tamanho vetor = 154, esperado = 90
#   Verificando b02_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b03_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b03_esp_2: tamanho vetor = 120, esperado = 90
#   Verificando b03_esp_3: tamanho vetor = 109, esperado = 90
#   Verificando b03_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando b04_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando b04_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando b04_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b05_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b05_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando b05_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando b05_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b06_esp_1: tamanho vetor = 101, esperado = 90
#   Verificando b06_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando b06_esp_3: tamanho vetor = 105, esperado = 90
#   Verificando b06_esp_4: tamanho vetor = 143, esperado = 90
#   Verificando b07_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b07_esp_2: tamanho vetor = 112, esperado = 90
#   Verificando b07_esp_3: tamanho vetor = 94, esperado = 90
#   Verificando b07_esp_4: tamanho vetor = 109, esperado = 90
#   Verificando b08_esp_1: tamanho vetor = 85, esperado = 90
#   Verificando b08_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b08_esp_3: tamanho vetor = 111, esperado = 90
#   Verificando b08_esp_4: tamanho vetor = 118, esperado = 90
#   Verificando b09_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b09_esp_2: tamanho vetor = 113, esperado = 90
#   Verificando b09_esp_3: tamanho vetor = 103, esperado = 90
#   Verificando b09_esp_4: tamanho vetor = 110, esperado = 90
#   Verificando b10_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando b10_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b10_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando b10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando b11_esp_1: tamanho vetor = 81, esperado = 90
#   Verificando b11_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b11_esp_3: tamanho vetor = 100, esperado = 90
#   Verificando b11_esp_4: tamanho vetor = 111, esperado = 90
#   Verificando c01_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando c01_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando c01_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando c01_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando c02_esp_1: tamanho vetor = 137, esperado = 90
#   Verificando c02_esp_2: tamanho vetor = 153, esperado = 90
#   Verificando c02_esp_3: tamanho vetor = 167, esperado = 90
#   Verificando c02_esp_4: tamanho vetor = 144, esperado = 90
#   Verificando c03_esp_1: tamanho vetor = 149, esperado = 90
#   Verificando c03_esp_2: tamanho vetor = 148, esperado = 90
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
#   Verificando c05_esp_2: tamanho vetor = 164, esperado = 90
#   Verificando c05_esp_3: tamanho vetor = 156, esperado = 90
#   Verificando c05_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando c06_esp_1: tamanho vetor = 76, esperado = 90
#   Verificando c06_esp_2: tamanho vetor = 71, esperado = 90
#   Verificando c06_esp_3: tamanho vetor = 79, esperado = 90
#   Verificando c06_esp_4: tamanho vetor = 99, esperado = 90
#   Verificando c07_esp_1: tamanho vetor = 170, esperado = 90
#   Verificando c07_esp_2: tamanho vetor = 126, esperado = 90
#   Verificando c07_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c07_esp_4: tamanho vetor = 183, esperado = 90
#   Verificando c08_esp_1: tamanho vetor = 162, esperado = 90
#   Verificando c08_esp_2: tamanho vetor = 141, esperado = 90
#   Verificando c08_esp_3: tamanho vetor = 149, esperado = 90
#   Verificando c08_esp_4: tamanho vetor = 174, esperado = 90
#   Verificando c09_esp_1: tamanho vetor = 159, esperado = 90
#   Verificando c09_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando c09_esp_3: tamanho vetor = 164, esperado = 90
#   Verificando c09_esp_4: tamanho vetor = 180, esperado = 90
#   Verificando c10_esp_1: tamanho vetor = 160, esperado = 90
#   Verificando c10_esp_2: tamanho vetor = 146, esperado = 90
#   Verificando c10_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c10_esp_4: tamanho vetor = 171, esperado = 90
#   Verificando c11_esp_1: tamanho vetor = 177, esperado = 90
#   Verificando c11_esp_2: tamanho vetor = 160, esperado = 90
#   Verificando c11_esp_3: tamanho vetor = 174, esperado = 90
#   Verificando c11_esp_4: tamanho vetor = 197, esperado = 90
#   Verificando d01_esp_1: tamanho vetor = 169, esperado = 90
#   Verificando d01_esp_2: tamanho vetor = 128, esperado = 90
#   Verificando d01_esp_3: tamanho vetor = 141, esperado = 90
#   Verificando d01_esp_4: tamanho vetor = 151, esperado = 90
#   Verificando d02_esp_1: tamanho vetor = 97, esperado = 90
#   Verificando d02_esp_2: tamanho vetor = 65, esperado = 90
#   Verificando d02_esp_3: tamanho vetor = 116, esperado = 90
#   Verificando d02_esp_4: tamanho vetor = 125, esperado = 90
#   Verificando d03_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando d03_esp_2: tamanho vetor = 109, esperado = 90
#   Verificando d03_esp_3: tamanho vetor = 104, esperado = 90
#   Verificando d03_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando d04_esp_1: tamanho vetor = 118, esperado = 90
#   Verificando d04_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando d04_esp_3: tamanho vetor = 169, esperado = 90
#   Verificando d04_esp_4: tamanho vetor = 158, esperado = 90
#   Verificando d05_esp_1: tamanho vetor = 89, esperado = 90
#   Verificando d05_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando d05_esp_3: tamanho vetor = 129, esperado = 90
#   Verificando d05_esp_4: tamanho vetor = 124, esperado = 90
#   Verificando d06_esp_1: tamanho vetor = 105, esperado = 90
#   Verificando d06_esp_2: tamanho vetor = 129, esperado = 90
#   Verificando d06_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando d06_esp_4: tamanho vetor = 149, esperado = 90
#   Verificando d07_esp_1: tamanho vetor = 107, esperado = 90
#   Verificando d07_esp_2: tamanho vetor = 117, esperado = 90
#   Verificando d07_esp_3: tamanho vetor = 159, esperado = 90
#   Verificando d07_esp_4: tamanho vetor = 135, esperado = 90
#   Verificando d08_esp_1: tamanho vetor = 166, esperado = 90
#   Verificando d08_esp_2: tamanho vetor = 115, esperado = 90
#   Verificando d08_esp_3: tamanho vetor = 130, esperado = 90
#   Verificando d08_esp_4: tamanho vetor = 165, esperado = 90
#   Verificando d09_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_2: tamanho vetor = 116, esperado = 90
#   Verificando d09_esp_3: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando d10_esp_1: tamanho vetor = 134, esperado = 90
#   Verificando d10_esp_2: tamanho vetor = 139, esperado = 90
#   Verificando d10_esp_3: tamanho vetor = 119, esperado = 90
#   Verificando d10_esp_4: tamanho vetor = 114, esperado = 90
#   Verificando d11_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando d11_esp_2: tamanho vetor = 110, esperado = 90
#   Verificando d11_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando d11_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando e04_esp_1: tamanho vetor = 130, esperado = 90
#   Verificando e04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando e04_esp_3: tamanho vetor = 127, esperado = 90
#   Verificando e04_esp_4: tamanho vetor = 130, esperado = 90
#   Verificando e05_esp_1: tamanho vetor = 121, esperado = 90
#   Verificando e05_esp_2: tamanho vetor = 105, esperado = 90
#   Verificando e05_esp_3: tamanho vetor = 123, esperado = 90
#   Verificando e05_esp_4: tamanho vetor = 119, esperado = 90
#   Verificando e06_esp_1: tamanho vetor = 143, esperado = 90
#   Verificando e06_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando e06_esp_3: tamanho vetor = 135, esperado = 90
#   Verificando e06_esp_4: tamanho vetor = 138, esperado = 90
# Subportadora 2:
#   Verificando vazio_1_esp_1: tamanho vetor = 22436, esperado = 350
#   Verificando vazio_1_esp_2: tamanho vetor = 17604, esperado = 350
#   Verificando vazio_1_esp_3: tamanho vetor = 21384, esperado = 350
#   Verificando vazio_1_esp_4: tamanho vetor = 23485, esperado = 350
#   Verificando vazio_2_esp_1: tamanho vetor = 149, esperado = 350
#   Verificando vazio_2_esp_2: tamanho vetor = 238, esperado = 350
#   Verificando vazio_2_esp_3: tamanho vetor = 177, esperado = 350
#   Verificando vazio_2_esp_4: tamanho vetor = 249, esperado = 350
#   Verificando a00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a00_esp_2: tamanho vetor = 118, esperado = 90
#   Verificando a00_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando a00_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando a01_esp_1: tamanho vetor = 41, esperado = 90
#   Verificando a01_esp_2: tamanho vetor = 42, esperado = 90
#   Verificando a01_esp_3: tamanho vetor = 54, esperado = 90
#   Verificando a01_esp_4: tamanho vetor = 74, esperado = 90
#   Verificando a09_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a09_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando a09_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando a09_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a10_esp_1: tamanho vetor = 129, esperado = 90
#   Verificando a10_esp_2: tamanho vetor = 90, esperado = 90
#   Verificando a10_esp_3: tamanho vetor = 81, esperado = 90
#   Verificando a10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a11_esp_1: tamanho vetor = 116, esperado = 90
#   Verificando a11_esp_2: tamanho vetor = 108, esperado = 90
#   Verificando a11_esp_3: tamanho vetor = 117, esperado = 90
#   Verificando a11_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b00_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b00_esp_3: tamanho vetor = 131, esperado = 90
#   Verificando b00_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b01_esp_1: tamanho vetor = 110, esperado = 90
#   Verificando b01_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b01_esp_3: tamanho vetor = 99, esperado = 90
#   Verificando b01_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b02_esp_1: tamanho vetor = 128, esperado = 90
#   Verificando b02_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b02_esp_3: tamanho vetor = 154, esperado = 90
#   Verificando b02_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b03_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b03_esp_2: tamanho vetor = 120, esperado = 90
#   Verificando b03_esp_3: tamanho vetor = 109, esperado = 90
#   Verificando b03_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando b04_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando b04_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando b04_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b05_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b05_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando b05_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando b05_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b06_esp_1: tamanho vetor = 101, esperado = 90
#   Verificando b06_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando b06_esp_3: tamanho vetor = 105, esperado = 90
#   Verificando b06_esp_4: tamanho vetor = 143, esperado = 90
#   Verificando b07_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b07_esp_2: tamanho vetor = 112, esperado = 90
#   Verificando b07_esp_3: tamanho vetor = 94, esperado = 90
#   Verificando b07_esp_4: tamanho vetor = 109, esperado = 90
#   Verificando b08_esp_1: tamanho vetor = 85, esperado = 90
#   Verificando b08_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b08_esp_3: tamanho vetor = 111, esperado = 90
#   Verificando b08_esp_4: tamanho vetor = 118, esperado = 90
#   Verificando b09_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b09_esp_2: tamanho vetor = 113, esperado = 90
#   Verificando b09_esp_3: tamanho vetor = 103, esperado = 90
#   Verificando b09_esp_4: tamanho vetor = 110, esperado = 90
#   Verificando b10_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando b10_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b10_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando b10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando b11_esp_1: tamanho vetor = 81, esperado = 90
#   Verificando b11_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b11_esp_3: tamanho vetor = 100, esperado = 90
#   Verificando b11_esp_4: tamanho vetor = 111, esperado = 90
#   Verificando c01_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando c01_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando c01_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando c01_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando c02_esp_1: tamanho vetor = 137, esperado = 90
#   Verificando c02_esp_2: tamanho vetor = 153, esperado = 90
#   Verificando c02_esp_3: tamanho vetor = 167, esperado = 90
#   Verificando c02_esp_4: tamanho vetor = 144, esperado = 90
#   Verificando c03_esp_1: tamanho vetor = 149, esperado = 90
#   Verificando c03_esp_2: tamanho vetor = 148, esperado = 90
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
#   Verificando c05_esp_2: tamanho vetor = 164, esperado = 90
#   Verificando c05_esp_3: tamanho vetor = 156, esperado = 90
#   Verificando c05_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando c06_esp_1: tamanho vetor = 76, esperado = 90
#   Verificando c06_esp_2: tamanho vetor = 71, esperado = 90
#   Verificando c06_esp_3: tamanho vetor = 79, esperado = 90
#   Verificando c06_esp_4: tamanho vetor = 99, esperado = 90
#   Verificando c07_esp_1: tamanho vetor = 170, esperado = 90
#   Verificando c07_esp_2: tamanho vetor = 126, esperado = 90
#   Verificando c07_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c07_esp_4: tamanho vetor = 183, esperado = 90
#   Verificando c08_esp_1: tamanho vetor = 162, esperado = 90
#   Verificando c08_esp_2: tamanho vetor = 141, esperado = 90
#   Verificando c08_esp_3: tamanho vetor = 149, esperado = 90
#   Verificando c08_esp_4: tamanho vetor = 174, esperado = 90
#   Verificando c09_esp_1: tamanho vetor = 159, esperado = 90
#   Verificando c09_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando c09_esp_3: tamanho vetor = 164, esperado = 90
#   Verificando c09_esp_4: tamanho vetor = 180, esperado = 90
#   Verificando c10_esp_1: tamanho vetor = 160, esperado = 90
#   Verificando c10_esp_2: tamanho vetor = 146, esperado = 90
#   Verificando c10_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c10_esp_4: tamanho vetor = 171, esperado = 90
#   Verificando c11_esp_1: tamanho vetor = 177, esperado = 90
#   Verificando c11_esp_2: tamanho vetor = 160, esperado = 90
#   Verificando c11_esp_3: tamanho vetor = 174, esperado = 90
#   Verificando c11_esp_4: tamanho vetor = 197, esperado = 90
#   Verificando d01_esp_1: tamanho vetor = 169, esperado = 90
#   Verificando d01_esp_2: tamanho vetor = 128, esperado = 90
#   Verificando d01_esp_3: tamanho vetor = 141, esperado = 90
#   Verificando d01_esp_4: tamanho vetor = 151, esperado = 90
#   Verificando d02_esp_1: tamanho vetor = 97, esperado = 90
#   Verificando d02_esp_2: tamanho vetor = 65, esperado = 90
#   Verificando d02_esp_3: tamanho vetor = 116, esperado = 90
#   Verificando d02_esp_4: tamanho vetor = 125, esperado = 90
#   Verificando d03_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando d03_esp_2: tamanho vetor = 109, esperado = 90
#   Verificando d03_esp_3: tamanho vetor = 104, esperado = 90
#   Verificando d03_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando d04_esp_1: tamanho vetor = 118, esperado = 90
#   Verificando d04_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando d04_esp_3: tamanho vetor = 169, esperado = 90
#   Verificando d04_esp_4: tamanho vetor = 158, esperado = 90
#   Verificando d05_esp_1: tamanho vetor = 89, esperado = 90
#   Verificando d05_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando d05_esp_3: tamanho vetor = 129, esperado = 90
#   Verificando d05_esp_4: tamanho vetor = 124, esperado = 90
#   Verificando d06_esp_1: tamanho vetor = 105, esperado = 90
#   Verificando d06_esp_2: tamanho vetor = 129, esperado = 90
#   Verificando d06_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando d06_esp_4: tamanho vetor = 149, esperado = 90
#   Verificando d07_esp_1: tamanho vetor = 107, esperado = 90
#   Verificando d07_esp_2: tamanho vetor = 117, esperado = 90
#   Verificando d07_esp_3: tamanho vetor = 159, esperado = 90
#   Verificando d07_esp_4: tamanho vetor = 135, esperado = 90
#   Verificando d08_esp_1: tamanho vetor = 166, esperado = 90
#   Verificando d08_esp_2: tamanho vetor = 115, esperado = 90
#   Verificando d08_esp_3: tamanho vetor = 130, esperado = 90
#   Verificando d08_esp_4: tamanho vetor = 165, esperado = 90
#   Verificando d09_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_2: tamanho vetor = 116, esperado = 90
#   Verificando d09_esp_3: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando d10_esp_1: tamanho vetor = 134, esperado = 90
#   Verificando d10_esp_2: tamanho vetor = 139, esperado = 90
#   Verificando d10_esp_3: tamanho vetor = 119, esperado = 90
#   Verificando d10_esp_4: tamanho vetor = 114, esperado = 90
#   Verificando d11_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando d11_esp_2: tamanho vetor = 110, esperado = 90
#   Verificando d11_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando d11_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando e04_esp_1: tamanho vetor = 130, esperado = 90
#   Verificando e04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando e04_esp_3: tamanho vetor = 127, esperado = 90
#   Verificando e04_esp_4: tamanho vetor = 130, esperado = 90
#   Verificando e05_esp_1: tamanho vetor = 121, esperado = 90
#   Verificando e05_esp_2: tamanho vetor = 105, esperado = 90
#   Verificando e05_esp_3: tamanho vetor = 123, esperado = 90
#   Verificando e05_esp_4: tamanho vetor = 119, esperado = 90
#   Verificando e06_esp_1: tamanho vetor = 143, esperado = 90
#   Verificando e06_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando e06_esp_3: tamanho vetor = 135, esperado = 90
#   Verificando e06_esp_4: tamanho vetor = 138, esperado = 90
# Subportadora 3:
#   Verificando vazio_1_esp_1: tamanho vetor = 22436, esperado = 350
#   Verificando vazio_1_esp_2: tamanho vetor = 17604, esperado = 350
#   Verificando vazio_1_esp_3: tamanho vetor = 21384, esperado = 350
#   Verificando vazio_1_esp_4: tamanho vetor = 23485, esperado = 350
#   Verificando vazio_2_esp_1: tamanho vetor = 149, esperado = 350
#   Verificando vazio_2_esp_2: tamanho vetor = 238, esperado = 350
#   Verificando vazio_2_esp_3: tamanho vetor = 177, esperado = 350
#   Verificando vazio_2_esp_4: tamanho vetor = 249, esperado = 350
#   Verificando a00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a00_esp_2: tamanho vetor = 118, esperado = 90
#   Verificando a00_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando a00_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando a01_esp_1: tamanho vetor = 41, esperado = 90
#   Verificando a01_esp_2: tamanho vetor = 42, esperado = 90
#   Verificando a01_esp_3: tamanho vetor = 54, esperado = 90
#   Verificando a01_esp_4: tamanho vetor = 74, esperado = 90
#   Verificando a09_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a09_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando a09_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando a09_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a10_esp_1: tamanho vetor = 129, esperado = 90
#   Verificando a10_esp_2: tamanho vetor = 90, esperado = 90
#   Verificando a10_esp_3: tamanho vetor = 81, esperado = 90
#   Verificando a10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a11_esp_1: tamanho vetor = 116, esperado = 90
#   Verificando a11_esp_2: tamanho vetor = 108, esperado = 90
#   Verificando a11_esp_3: tamanho vetor = 117, esperado = 90
#   Verificando a11_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b00_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b00_esp_3: tamanho vetor = 131, esperado = 90
#   Verificando b00_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b01_esp_1: tamanho vetor = 110, esperado = 90
#   Verificando b01_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b01_esp_3: tamanho vetor = 99, esperado = 90
#   Verificando b01_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b02_esp_1: tamanho vetor = 128, esperado = 90
#   Verificando b02_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b02_esp_3: tamanho vetor = 154, esperado = 90
#   Verificando b02_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b03_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b03_esp_2: tamanho vetor = 120, esperado = 90
#   Verificando b03_esp_3: tamanho vetor = 109, esperado = 90
#   Verificando b03_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando b04_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando b04_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando b04_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b05_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b05_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando b05_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando b05_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b06_esp_1: tamanho vetor = 101, esperado = 90
#   Verificando b06_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando b06_esp_3: tamanho vetor = 105, esperado = 90
#   Verificando b06_esp_4: tamanho vetor = 143, esperado = 90
#   Verificando b07_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b07_esp_2: tamanho vetor = 112, esperado = 90
#   Verificando b07_esp_3: tamanho vetor = 94, esperado = 90
#   Verificando b07_esp_4: tamanho vetor = 109, esperado = 90
#   Verificando b08_esp_1: tamanho vetor = 85, esperado = 90
#   Verificando b08_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b08_esp_3: tamanho vetor = 111, esperado = 90
#   Verificando b08_esp_4: tamanho vetor = 118, esperado = 90
#   Verificando b09_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b09_esp_2: tamanho vetor = 113, esperado = 90
#   Verificando b09_esp_3: tamanho vetor = 103, esperado = 90
#   Verificando b09_esp_4: tamanho vetor = 110, esperado = 90
#   Verificando b10_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando b10_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b10_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando b10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando b11_esp_1: tamanho vetor = 81, esperado = 90
#   Verificando b11_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b11_esp_3: tamanho vetor = 100, esperado = 90
#   Verificando b11_esp_4: tamanho vetor = 111, esperado = 90
#   Verificando c01_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando c01_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando c01_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando c01_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando c02_esp_1: tamanho vetor = 137, esperado = 90
#   Verificando c02_esp_2: tamanho vetor = 153, esperado = 90
#   Verificando c02_esp_3: tamanho vetor = 167, esperado = 90
#   Verificando c02_esp_4: tamanho vetor = 144, esperado = 90
#   Verificando c03_esp_1: tamanho vetor = 149, esperado = 90
#   Verificando c03_esp_2: tamanho vetor = 148, esperado = 90
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
#   Verificando c05_esp_2: tamanho vetor = 164, esperado = 90
#   Verificando c05_esp_3: tamanho vetor = 156, esperado = 90
#   Verificando c05_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando c06_esp_1: tamanho vetor = 76, esperado = 90
#   Verificando c06_esp_2: tamanho vetor = 71, esperado = 90
#   Verificando c06_esp_3: tamanho vetor = 79, esperado = 90
#   Verificando c06_esp_4: tamanho vetor = 99, esperado = 90
#   Verificando c07_esp_1: tamanho vetor = 170, esperado = 90
#   Verificando c07_esp_2: tamanho vetor = 126, esperado = 90
#   Verificando c07_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c07_esp_4: tamanho vetor = 183, esperado = 90
#   Verificando c08_esp_1: tamanho vetor = 162, esperado = 90
#   Verificando c08_esp_2: tamanho vetor = 141, esperado = 90
#   Verificando c08_esp_3: tamanho vetor = 149, esperado = 90
#   Verificando c08_esp_4: tamanho vetor = 174, esperado = 90
#   Verificando c09_esp_1: tamanho vetor = 159, esperado = 90
#   Verificando c09_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando c09_esp_3: tamanho vetor = 164, esperado = 90
#   Verificando c09_esp_4: tamanho vetor = 180, esperado = 90
#   Verificando c10_esp_1: tamanho vetor = 160, esperado = 90
#   Verificando c10_esp_2: tamanho vetor = 146, esperado = 90
#   Verificando c10_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c10_esp_4: tamanho vetor = 171, esperado = 90
#   Verificando c11_esp_1: tamanho vetor = 177, esperado = 90
#   Verificando c11_esp_2: tamanho vetor = 160, esperado = 90
#   Verificando c11_esp_3: tamanho vetor = 174, esperado = 90
#   Verificando c11_esp_4: tamanho vetor = 197, esperado = 90
#   Verificando d01_esp_1: tamanho vetor = 169, esperado = 90
#   Verificando d01_esp_2: tamanho vetor = 128, esperado = 90
#   Verificando d01_esp_3: tamanho vetor = 141, esperado = 90
#   Verificando d01_esp_4: tamanho vetor = 151, esperado = 90
#   Verificando d02_esp_1: tamanho vetor = 97, esperado = 90
#   Verificando d02_esp_2: tamanho vetor = 65, esperado = 90
#   Verificando d02_esp_3: tamanho vetor = 116, esperado = 90
#   Verificando d02_esp_4: tamanho vetor = 125, esperado = 90
#   Verificando d03_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando d03_esp_2: tamanho vetor = 109, esperado = 90
#   Verificando d03_esp_3: tamanho vetor = 104, esperado = 90
#   Verificando d03_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando d04_esp_1: tamanho vetor = 118, esperado = 90
#   Verificando d04_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando d04_esp_3: tamanho vetor = 169, esperado = 90
#   Verificando d04_esp_4: tamanho vetor = 158, esperado = 90
#   Verificando d05_esp_1: tamanho vetor = 89, esperado = 90
#   Verificando d05_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando d05_esp_3: tamanho vetor = 129, esperado = 90
#   Verificando d05_esp_4: tamanho vetor = 124, esperado = 90
#   Verificando d06_esp_1: tamanho vetor = 105, esperado = 90
#   Verificando d06_esp_2: tamanho vetor = 129, esperado = 90
#   Verificando d06_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando d06_esp_4: tamanho vetor = 149, esperado = 90
#   Verificando d07_esp_1: tamanho vetor = 107, esperado = 90
#   Verificando d07_esp_2: tamanho vetor = 117, esperado = 90
#   Verificando d07_esp_3: tamanho vetor = 159, esperado = 90
#   Verificando d07_esp_4: tamanho vetor = 135, esperado = 90
#   Verificando d08_esp_1: tamanho vetor = 166, esperado = 90
#   Verificando d08_esp_2: tamanho vetor = 115, esperado = 90
#   Verificando d08_esp_3: tamanho vetor = 130, esperado = 90
#   Verificando d08_esp_4: tamanho vetor = 165, esperado = 90
#   Verificando d09_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_2: tamanho vetor = 116, esperado = 90
#   Verificando d09_esp_3: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando d10_esp_1: tamanho vetor = 134, esperado = 90
#   Verificando d10_esp_2: tamanho vetor = 139, esperado = 90
#   Verificando d10_esp_3: tamanho vetor = 119, esperado = 90
#   Verificando d10_esp_4: tamanho vetor = 114, esperado = 90
#   Verificando d11_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando d11_esp_2: tamanho vetor = 110, esperado = 90
#   Verificando d11_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando d11_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando e04_esp_1: tamanho vetor = 130, esperado = 90
#   Verificando e04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando e04_esp_3: tamanho vetor = 127, esperado = 90
#   Verificando e04_esp_4: tamanho vetor = 130, esperado = 90
#   Verificando e05_esp_1: tamanho vetor = 121, esperado = 90
#   Verificando e05_esp_2: tamanho vetor = 105, esperado = 90
#   Verificando e05_esp_3: tamanho vetor = 123, esperado = 90
#   Verificando e05_esp_4: tamanho vetor = 119, esperado = 90
#   Verificando e06_esp_1: tamanho vetor = 143, esperado = 90
#   Verificando e06_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando e06_esp_3: tamanho vetor = 135, esperado = 90
#   Verificando e06_esp_4: tamanho vetor = 138, esperado = 90
# Subportadora 4:
#   Verificando vazio_1_esp_1: tamanho vetor = 22436, esperado = 350
#   Verificando vazio_1_esp_2: tamanho vetor = 17604, esperado = 350
#   Verificando vazio_1_esp_3: tamanho vetor = 21384, esperado = 350
#   Verificando vazio_1_esp_4: tamanho vetor = 23485, esperado = 350
#   Verificando vazio_2_esp_1: tamanho vetor = 149, esperado = 350
#   Verificando vazio_2_esp_2: tamanho vetor = 238, esperado = 350
#   Verificando vazio_2_esp_3: tamanho vetor = 177, esperado = 350
#   Verificando vazio_2_esp_4: tamanho vetor = 249, esperado = 350
#   Verificando a00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a00_esp_2: tamanho vetor = 118, esperado = 90
#   Verificando a00_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando a00_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando a01_esp_1: tamanho vetor = 41, esperado = 90
#   Verificando a01_esp_2: tamanho vetor = 42, esperado = 90
#   Verificando a01_esp_3: tamanho vetor = 54, esperado = 90
#   Verificando a01_esp_4: tamanho vetor = 74, esperado = 90
#   Verificando a09_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a09_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando a09_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando a09_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a10_esp_1: tamanho vetor = 129, esperado = 90
#   Verificando a10_esp_2: tamanho vetor = 90, esperado = 90
#   Verificando a10_esp_3: tamanho vetor = 81, esperado = 90
#   Verificando a10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a11_esp_1: tamanho vetor = 116, esperado = 90
#   Verificando a11_esp_2: tamanho vetor = 108, esperado = 90
#   Verificando a11_esp_3: tamanho vetor = 117, esperado = 90
#   Verificando a11_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b00_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b00_esp_3: tamanho vetor = 131, esperado = 90
#   Verificando b00_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b01_esp_1: tamanho vetor = 110, esperado = 90
#   Verificando b01_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b01_esp_3: tamanho vetor = 99, esperado = 90
#   Verificando b01_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b02_esp_1: tamanho vetor = 128, esperado = 90
#   Verificando b02_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b02_esp_3: tamanho vetor = 154, esperado = 90
#   Verificando b02_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b03_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b03_esp_2: tamanho vetor = 120, esperado = 90
#   Verificando b03_esp_3: tamanho vetor = 109, esperado = 90
#   Verificando b03_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando b04_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando b04_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando b04_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b05_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b05_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando b05_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando b05_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b06_esp_1: tamanho vetor = 101, esperado = 90
#   Verificando b06_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando b06_esp_3: tamanho vetor = 105, esperado = 90
#   Verificando b06_esp_4: tamanho vetor = 143, esperado = 90
#   Verificando b07_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b07_esp_2: tamanho vetor = 112, esperado = 90
#   Verificando b07_esp_3: tamanho vetor = 94, esperado = 90
#   Verificando b07_esp_4: tamanho vetor = 109, esperado = 90
#   Verificando b08_esp_1: tamanho vetor = 85, esperado = 90
#   Verificando b08_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b08_esp_3: tamanho vetor = 111, esperado = 90
#   Verificando b08_esp_4: tamanho vetor = 118, esperado = 90
#   Verificando b09_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b09_esp_2: tamanho vetor = 113, esperado = 90
#   Verificando b09_esp_3: tamanho vetor = 103, esperado = 90
#   Verificando b09_esp_4: tamanho vetor = 110, esperado = 90
#   Verificando b10_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando b10_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b10_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando b10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando b11_esp_1: tamanho vetor = 81, esperado = 90
#   Verificando b11_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b11_esp_3: tamanho vetor = 100, esperado = 90
#   Verificando b11_esp_4: tamanho vetor = 111, esperado = 90
#   Verificando c01_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando c01_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando c01_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando c01_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando c02_esp_1: tamanho vetor = 137, esperado = 90
#   Verificando c02_esp_2: tamanho vetor = 153, esperado = 90
#   Verificando c02_esp_3: tamanho vetor = 167, esperado = 90
#   Verificando c02_esp_4: tamanho vetor = 144, esperado = 90
#   Verificando c03_esp_1: tamanho vetor = 149, esperado = 90
#   Verificando c03_esp_2: tamanho vetor = 148, esperado = 90
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
# ...
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
#   Verificando c05_esp_2: tamanho vetor = 164, esperado = 90
#   Verificando c05_esp_3: tamanho vetor = 156, esperado = 90
#   Verificando c05_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando c06_esp_1: tamanho vetor = 76, esperado = 90
#   Verificando c06_esp_2: tamanho vetor = 71, esperado = 90
#   Verificando c06_esp_3: tamanho vetor = 79, esperado = 90
#   Verificando c06_esp_4: tamanho vetor = 99, esperado = 90
#   Verificando c07_esp_1: tamanho vetor = 170, esperado = 90
#   Verificando c07_esp_2: tamanho vetor = 126, esperado = 90
#   Verificando c07_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c07_esp_4: tamanho vetor = 183, esperado = 90
#   Verificando c08_esp_1: tamanho vetor = 162, esperado = 90
#   Verificando c08_esp_2: tamanho vetor = 141, esperado = 90
#   Verificando c08_esp_3: tamanho vetor = 149, esperado = 90
#   Verificando c08_esp_4: tamanho vetor = 174, esperado = 90
#   Verificando c09_esp_1: tamanho vetor = 159, esperado = 90
#   Verificando c09_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando c09_esp_3: tamanho vetor = 164, esperado = 90
#   Verificando c09_esp_4: tamanho vetor = 180, esperado = 90
#   Verificando c10_esp_1: tamanho vetor = 160, esperado = 90
#   Verificando c10_esp_2: tamanho vetor = 146, esperado = 90
#   Verificando c10_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c10_esp_4: tamanho vetor = 171, esperado = 90
#   Verificando c11_esp_1: tamanho vetor = 177, esperado = 90
#   Verificando c11_esp_2: tamanho vetor = 160, esperado = 90
#   Verificando c11_esp_3: tamanho vetor = 174, esperado = 90
#   Verificando c11_esp_4: tamanho vetor = 197, esperado = 90
#   Verificando d01_esp_1: tamanho vetor = 169, esperado = 90
#   Verificando d01_esp_2: tamanho vetor = 128, esperado = 90
#   Verificando d01_esp_3: tamanho vetor = 141, esperado = 90
#   Verificando d01_esp_4: tamanho vetor = 151, esperado = 90
#   Verificando d02_esp_1: tamanho vetor = 97, esperado = 90
#   Verificando d02_esp_2: tamanho vetor = 65, esperado = 90
#   Verificando d02_esp_3: tamanho vetor = 116, esperado = 90
#   Verificando d02_esp_4: tamanho vetor = 125, esperado = 90
#   Verificando d03_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando d03_esp_2: tamanho vetor = 109, esperado = 90
#   Verificando d03_esp_3: tamanho vetor = 104, esperado = 90
#   Verificando d03_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando d04_esp_1: tamanho vetor = 118, esperado = 90
#   Verificando d04_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando d04_esp_3: tamanho vetor = 169, esperado = 90
#   Verificando d04_esp_4: tamanho vetor = 158, esperado = 90
#   Verificando d05_esp_1: tamanho vetor = 89, esperado = 90
#   Verificando d05_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando d05_esp_3: tamanho vetor = 129, esperado = 90
#   Verificando d05_esp_4: tamanho vetor = 124, esperado = 90
#   Verificando d06_esp_1: tamanho vetor = 105, esperado = 90
#   Verificando d06_esp_2: tamanho vetor = 129, esperado = 90
#   Verificando d06_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando d06_esp_4: tamanho vetor = 149, esperado = 90
#   Verificando d07_esp_1: tamanho vetor = 107, esperado = 90
#   Verificando d07_esp_2: tamanho vetor = 117, esperado = 90
#   Verificando d07_esp_3: tamanho vetor = 159, esperado = 90
#   Verificando d07_esp_4: tamanho vetor = 135, esperado = 90
#   Verificando d08_esp_1: tamanho vetor = 166, esperado = 90
#   Verificando d08_esp_2: tamanho vetor = 115, esperado = 90
#   Verificando d08_esp_3: tamanho vetor = 130, esperado = 90
#   Verificando d08_esp_4: tamanho vetor = 165, esperado = 90
#   Verificando d09_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_2: tamanho vetor = 116, esperado = 90
#   Verificando d09_esp_3: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando d10_esp_1: tamanho vetor = 134, esperado = 90
#   Verificando d10_esp_2: tamanho vetor = 139, esperado = 90
#   Verificando d10_esp_3: tamanho vetor = 119, esperado = 90
#   Verificando d10_esp_4: tamanho vetor = 114, esperado = 90
#   Verificando d11_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando d11_esp_2: tamanho vetor = 110, esperado = 90
#   Verificando d11_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando d11_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando e04_esp_1: tamanho vetor = 130, esperado = 90
#   Verificando e04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando e04_esp_3: tamanho vetor = 127, esperado = 90
#   Verificando e04_esp_4: tamanho vetor = 130, esperado = 90
#   Verificando e05_esp_1: tamanho vetor = 121, esperado = 90
#   Verificando e05_esp_2: tamanho vetor = 105, esperado = 90
#   Verificando e05_esp_3: tamanho vetor = 123, esperado = 90
#   Verificando e05_esp_4: tamanho vetor = 119, esperado = 90
#   Verificando e06_esp_1: tamanho vetor = 143, esperado = 90
#   Verificando e06_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando e06_esp_3: tamanho vetor = 135, esperado = 90
#   Verificando e06_esp_4: tamanho vetor = 138, esperado = 90
# Subportadora 50:
#   Verificando vazio_1_esp_1: tamanho vetor = 22436, esperado = 350
#   Verificando vazio_1_esp_2: tamanho vetor = 17604, esperado = 350
#   Verificando vazio_1_esp_3: tamanho vetor = 21384, esperado = 350
#   Verificando vazio_1_esp_4: tamanho vetor = 23485, esperado = 350
#   Verificando vazio_2_esp_1: tamanho vetor = 149, esperado = 350
#   Verificando vazio_2_esp_2: tamanho vetor = 238, esperado = 350
#   Verificando vazio_2_esp_3: tamanho vetor = 177, esperado = 350
#   Verificando vazio_2_esp_4: tamanho vetor = 249, esperado = 350
#   Verificando a00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a00_esp_2: tamanho vetor = 118, esperado = 90
#   Verificando a00_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando a00_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando a01_esp_1: tamanho vetor = 41, esperado = 90
#   Verificando a01_esp_2: tamanho vetor = 42, esperado = 90
#   Verificando a01_esp_3: tamanho vetor = 54, esperado = 90
#   Verificando a01_esp_4: tamanho vetor = 74, esperado = 90
#   Verificando a09_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando a09_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando a09_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando a09_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a10_esp_1: tamanho vetor = 129, esperado = 90
#   Verificando a10_esp_2: tamanho vetor = 90, esperado = 90
#   Verificando a10_esp_3: tamanho vetor = 81, esperado = 90
#   Verificando a10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando a11_esp_1: tamanho vetor = 116, esperado = 90
#   Verificando a11_esp_2: tamanho vetor = 108, esperado = 90
#   Verificando a11_esp_3: tamanho vetor = 117, esperado = 90
#   Verificando a11_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b00_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b00_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b00_esp_3: tamanho vetor = 131, esperado = 90
#   Verificando b00_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b01_esp_1: tamanho vetor = 110, esperado = 90
#   Verificando b01_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b01_esp_3: tamanho vetor = 99, esperado = 90
#   Verificando b01_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b02_esp_1: tamanho vetor = 128, esperado = 90
#   Verificando b02_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b02_esp_3: tamanho vetor = 154, esperado = 90
#   Verificando b02_esp_4: tamanho vetor = 115, esperado = 90
#   Verificando b03_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b03_esp_2: tamanho vetor = 120, esperado = 90
#   Verificando b03_esp_3: tamanho vetor = 109, esperado = 90
#   Verificando b03_esp_4: tamanho vetor = 108, esperado = 90
#   Verificando b04_esp_1: tamanho vetor = 100, esperado = 90
#   Verificando b04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando b04_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando b04_esp_4: tamanho vetor = 126, esperado = 90
#   Verificando b05_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b05_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando b05_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando b05_esp_4: tamanho vetor = 120, esperado = 90
#   Verificando b06_esp_1: tamanho vetor = 101, esperado = 90
#   Verificando b06_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando b06_esp_3: tamanho vetor = 105, esperado = 90
#   Verificando b06_esp_4: tamanho vetor = 143, esperado = 90
#   Verificando b07_esp_1: tamanho vetor = 91, esperado = 90
#   Verificando b07_esp_2: tamanho vetor = 112, esperado = 90
#   Verificando b07_esp_3: tamanho vetor = 94, esperado = 90
#   Verificando b07_esp_4: tamanho vetor = 109, esperado = 90
#   Verificando b08_esp_1: tamanho vetor = 85, esperado = 90
#   Verificando b08_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando b08_esp_3: tamanho vetor = 111, esperado = 90
#   Verificando b08_esp_4: tamanho vetor = 118, esperado = 90
#   Verificando b09_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando b09_esp_2: tamanho vetor = 113, esperado = 90
#   Verificando b09_esp_3: tamanho vetor = 103, esperado = 90
#   Verificando b09_esp_4: tamanho vetor = 110, esperado = 90
#   Verificando b10_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando b10_esp_2: tamanho vetor = 86, esperado = 90
#   Verificando b10_esp_3: tamanho vetor = 138, esperado = 90
#   Verificando b10_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando b11_esp_1: tamanho vetor = 81, esperado = 90
#   Verificando b11_esp_2: tamanho vetor = 84, esperado = 90
#   Verificando b11_esp_3: tamanho vetor = 100, esperado = 90
#   Verificando b11_esp_4: tamanho vetor = 111, esperado = 90
#   Verificando c01_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando c01_esp_2: tamanho vetor = 98, esperado = 90
#   Verificando c01_esp_3: tamanho vetor = 114, esperado = 90
#   Verificando c01_esp_4: tamanho vetor = 113, esperado = 90
#   Verificando c02_esp_1: tamanho vetor = 137, esperado = 90
#   Verificando c02_esp_2: tamanho vetor = 153, esperado = 90
#   Verificando c02_esp_3: tamanho vetor = 167, esperado = 90
#   Verificando c02_esp_4: tamanho vetor = 144, esperado = 90
#   Verificando c03_esp_1: tamanho vetor = 149, esperado = 90
#   Verificando c03_esp_2: tamanho vetor = 148, esperado = 90
#   Verificando c03_esp_3: tamanho vetor = 179, esperado = 90
#   Verificando c03_esp_4: tamanho vetor = 168, esperado = 90
#   Verificando c04_esp_1: tamanho vetor = 152, esperado = 90
#   Verificando c04_esp_2: tamanho vetor = 119, esperado = 90
#   Verificando c04_esp_3: tamanho vetor = 177, esperado = 90
#   Verificando c04_esp_4: tamanho vetor = 172, esperado = 90
#   Verificando c05_esp_1: tamanho vetor = 168, esperado = 90
#   Verificando c05_esp_2: tamanho vetor = 164, esperado = 90
#   Verificando c05_esp_3: tamanho vetor = 156, esperado = 90
#   Verificando c05_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando c06_esp_1: tamanho vetor = 76, esperado = 90
#   Verificando c06_esp_2: tamanho vetor = 71, esperado = 90
#   Verificando c06_esp_3: tamanho vetor = 79, esperado = 90
#   Verificando c06_esp_4: tamanho vetor = 99, esperado = 90
#   Verificando c07_esp_1: tamanho vetor = 170, esperado = 90
#   Verificando c07_esp_2: tamanho vetor = 126, esperado = 90
#   Verificando c07_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c07_esp_4: tamanho vetor = 183, esperado = 90
#   Verificando c08_esp_1: tamanho vetor = 162, esperado = 90
#   Verificando c08_esp_2: tamanho vetor = 141, esperado = 90
#   Verificando c08_esp_3: tamanho vetor = 149, esperado = 90
#   Verificando c08_esp_4: tamanho vetor = 174, esperado = 90
#   Verificando c09_esp_1: tamanho vetor = 159, esperado = 90
#   Verificando c09_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando c09_esp_3: tamanho vetor = 164, esperado = 90
#   Verificando c09_esp_4: tamanho vetor = 180, esperado = 90
#   Verificando c10_esp_1: tamanho vetor = 160, esperado = 90
#   Verificando c10_esp_2: tamanho vetor = 146, esperado = 90
#   Verificando c10_esp_3: tamanho vetor = 158, esperado = 90
#   Verificando c10_esp_4: tamanho vetor = 171, esperado = 90
#   Verificando c11_esp_1: tamanho vetor = 177, esperado = 90
#   Verificando c11_esp_2: tamanho vetor = 160, esperado = 90
#   Verificando c11_esp_3: tamanho vetor = 174, esperado = 90
#   Verificando c11_esp_4: tamanho vetor = 197, esperado = 90
#   Verificando d01_esp_1: tamanho vetor = 169, esperado = 90
#   Verificando d01_esp_2: tamanho vetor = 128, esperado = 90
#   Verificando d01_esp_3: tamanho vetor = 141, esperado = 90
#   Verificando d01_esp_4: tamanho vetor = 151, esperado = 90
#   Verificando d02_esp_1: tamanho vetor = 97, esperado = 90
#   Verificando d02_esp_2: tamanho vetor = 65, esperado = 90
#   Verificando d02_esp_3: tamanho vetor = 116, esperado = 90
#   Verificando d02_esp_4: tamanho vetor = 125, esperado = 90
#   Verificando d03_esp_1: tamanho vetor = 123, esperado = 90
#   Verificando d03_esp_2: tamanho vetor = 109, esperado = 90
#   Verificando d03_esp_3: tamanho vetor = 104, esperado = 90
#   Verificando d03_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando d04_esp_1: tamanho vetor = 118, esperado = 90
#   Verificando d04_esp_2: tamanho vetor = 102, esperado = 90
#   Verificando d04_esp_3: tamanho vetor = 169, esperado = 90
#   Verificando d04_esp_4: tamanho vetor = 158, esperado = 90
#   Verificando d05_esp_1: tamanho vetor = 89, esperado = 90
#   Verificando d05_esp_2: tamanho vetor = 88, esperado = 90
#   Verificando d05_esp_3: tamanho vetor = 129, esperado = 90
#   Verificando d05_esp_4: tamanho vetor = 124, esperado = 90
#   Verificando d06_esp_1: tamanho vetor = 105, esperado = 90
#   Verificando d06_esp_2: tamanho vetor = 129, esperado = 90
#   Verificando d06_esp_3: tamanho vetor = 110, esperado = 90
#   Verificando d06_esp_4: tamanho vetor = 149, esperado = 90
#   Verificando d07_esp_1: tamanho vetor = 107, esperado = 90
#   Verificando d07_esp_2: tamanho vetor = 117, esperado = 90
#   Verificando d07_esp_3: tamanho vetor = 159, esperado = 90
#   Verificando d07_esp_4: tamanho vetor = 135, esperado = 90
#   Verificando d08_esp_1: tamanho vetor = 166, esperado = 90
#   Verificando d08_esp_2: tamanho vetor = 115, esperado = 90
#   Verificando d08_esp_3: tamanho vetor = 130, esperado = 90
#   Verificando d08_esp_4: tamanho vetor = 165, esperado = 90
#   Verificando d09_esp_1: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_2: tamanho vetor = 116, esperado = 90
#   Verificando d09_esp_3: tamanho vetor = 140, esperado = 90
#   Verificando d09_esp_4: tamanho vetor = 148, esperado = 90
#   Verificando d10_esp_1: tamanho vetor = 134, esperado = 90
#   Verificando d10_esp_2: tamanho vetor = 139, esperado = 90
#   Verificando d10_esp_3: tamanho vetor = 119, esperado = 90
#   Verificando d10_esp_4: tamanho vetor = 114, esperado = 90
#   Verificando d11_esp_1: tamanho vetor = 125, esperado = 90
#   Verificando d11_esp_2: tamanho vetor = 110, esperado = 90
#   Verificando d11_esp_3: tamanho vetor = 101, esperado = 90
#   Verificando d11_esp_4: tamanho vetor = 136, esperado = 90
#   Verificando e04_esp_1: tamanho vetor = 130, esperado = 90
#   Verificando e04_esp_2: tamanho vetor = 97, esperado = 90
#   Verificando e04_esp_3: tamanho vetor = 127, esperado = 90
#   Verificando e04_esp_4: tamanho vetor = 130, esperado = 90
#   Verificando e05_esp_1: tamanho vetor = 121, esperado = 90
#   Verificando e05_esp_2: tamanho vetor = 105, esperado = 90
#   Verificando e05_esp_3: tamanho vetor = 123, esperado = 90
#   Verificando e05_esp_4: tamanho vetor = 119, esperado = 90
#   Verificando e06_esp_1: tamanho vetor = 143, esperado = 90
#   Verificando e06_esp_2: tamanho vetor = 155, esperado = 90
#   Verificando e06_esp_3: tamanho vetor = 135, esperado = 90
#   Verificando e06_esp_4: tamanho vetor = 138, esperado = 90

# %%
dados_loureiro: dados_map = {}
dados_diana: dados_map = {}
dados_afinar: dados_map = {}

dados_loureiro = criar_dataset(posicoes, tamanhos, magnitudes_loureiro)
dados_diana = criar_dataset(posicoes, tamanhos_diana, magnitudes_diana)
dados_afinar = criar_dataset(posicoes_afinar, tamanhos_afinar, magnitudes_afinadas)

# %%
size_vazio: int = 0
size_com: int = 0

for sc in subcarriers:
    for posicao in posicoes:
        for esp_id in esps_id:
            if posicao.startswith("vazio"):
                size_vazio += dados_loureiro[sc][f"{posicao}_esp_{esp_id}"].shape[0]
            else:
                size_com += dados_loureiro[sc][f"{posicao}_esp_{esp_id}"].shape[0]

print(f"Tamanho vetores vazio: {size_vazio}")
print(f"Tamanho vetores com pessoa: {size_com}")
# Out:
# Tamanho vetores vazio: 112863
# Tamanho vetores com pessoa: 757452

# %%
print(magnitudes_loureiro["a00"]["esp_1"].shape)
print(dados_loureiro[subcarriers[0]]["a00_esp_1"].shape)

print(magnitudes_loureiro["c06"]["esp_2"].shape)
print(dados_loureiro[subcarriers[0]]["c06_esp_2"].shape)

print(magnitudes_loureiro["vazio_1"]["esp_1"].shape)
print(dados_loureiro[subcarriers[0]]["vazio_1_esp_1"].shape)
# Out:
# (100, 51)
# (90,)
# (71, 51)
# (71,)
# (22436, 51)
# (350,)

# %% [markdown]
# Normalização de dados "normalizados"

# %%
normalizados_loureiro: dados_map = {}
normalizados_diana: dados_map = {}
normalizados_afinar: dados_map = {}

normalizados_loureiro = normalizar_vetores(posicoes, dados_loureiro, medias_c06)
normalizados_diana = normalizar_vetores(posicoes, dados_diana, medias_c06)
normalizados_afinar = normalizar_vetores_afinar(
    posicoes_afinar, dados_afinar, medias_c06
)

# %% [markdown]
# Mean, std, max

# %%
tamanho_janela: int = 10
step: int = 3
W: int = 27  # nº de janelas fixas para "com pessoa"
G: int = 60  # nº de janelas fixas para "dados_afinar"
# Estes valores diferentes são estranhos

media_loureiro: dados_map = {sc: {} for sc in subcarriers}
media_diana: dados_map = {sc: {} for sc in subcarriers}
media_afinar: dados_map = {sc: {} for sc in subcarriers}

std_loureiro: dados_map = {sc: {} for sc in subcarriers}
std_diana: dados_map = {sc: {} for sc in subcarriers}
std_afinar: dados_map = {sc: {} for sc in subcarriers}

max_loureiro: dados_map = {sc: {} for sc in subcarriers}
max_diana: dados_map = {sc: {} for sc in subcarriers}
max_afinar: dados_map = {sc: {} for sc in subcarriers}

for posicao in posicoes:
    for esp_id in esps_id:
        chave = f"{posicao}_esp_{esp_id}"
        for sc in subcarriers:
            valores_l = normalizados_loureiro[sc][chave]
            valores_d = normalizados_diana[sc][chave]

            if posicao.startswith(
                "vazio"
            ):  # Porque este step? Não sei o impacto final, mas isto parece-me batota...
                # mantém todas as janelas possíveis, sem truncar
                media_l = media_grupos_overlap(valores_l, tamanho_janela, step)
                std_l = std_grupos_overlap(valores_l, tamanho_janela, step)
                m_l = max_grupos_overlap(valores_l, tamanho_janela, step)

                media_d = media_grupos_overlap(valores_d, tamanho_janela, step)
                std_d = std_grupos_overlap(valores_d, tamanho_janela, step)
                m_d = max_grupos_overlap(valores_d, tamanho_janela, step)

            else:
                # força W janelas idênticas
                media_l = media_fixed(valores_l, tamanho_janela, W)
                std_l = std_fixed(valores_l, tamanho_janela, W)
                m_l = max_fixed(valores_l, tamanho_janela, W)

                media_d = media_fixed(valores_d, tamanho_janela, W)
                std_d = std_fixed(valores_d, tamanho_janela, W)
                m_d = max_fixed(valores_d, tamanho_janela, W)

            media_loureiro[sc][chave] = media_l
            std_loureiro[sc][chave] = std_l
            max_loureiro[sc][chave] = m_l

            media_diana[sc][chave] = media_d
            std_diana[sc][chave] = std_d
            max_diana[sc][chave] = m_d

for posicao in posicoes_afinar:
    for esp_id in esps_id:
        chave = f"{posicao}_esp_{esp_id}"
        for sc in subcarriers:
            v = normalizados_afinar[sc][chave]
            media = media_fixed(v, tamanho_janela, G)
            std = std_fixed(v, tamanho_janela, G)
            max = max_fixed(v, tamanho_janela, G)

            media_afinar[sc][chave] = media
            std_afinar[sc][chave] = std
            max_afinar[sc][chave] = max

# %% [markdown]
# #### *ML Pre Processing*

# %% [markdown]
# ##### Tabela colunas

# %%
subcarriers_map: dict[int, int] = {i + 1: sc for i, sc in enumerate(subcarriers)}

# dicionários para guardar cada coluna
coluna_media: dict[str, np.ndarray] = {}
coluna_std: dict[str, np.ndarray] = {}
coluna_max: dict[str, np.ndarray] = {}

# dicionários para guardar cada coluna
coluna_media_afinar: dict[str, np.ndarray] = {}
coluna_std_afinar: dict[str, np.ndarray] = {}
coluna_max_afinar: dict[str, np.ndarray] = {}

for sc_label, sc in subcarriers_map.items():
    for esp_id in esps_id:
        # nome da coluna
        name_mean = f"Mean sc_{sc_label} esp_{esp_id}"
        name_std = f"Std sc_{sc_label} esp_{esp_id}"
        name_max = f"Max sc_{sc_label} esp_{esp_id}"

        sequencia_mean, sequencia_std, sequencia_max = [], [], []

        # 1) SEM PESSOA: primeiro Loureiro, depois Diana
        sequencia_mean.append(media_loureiro[sc][f"vazio_1_esp_{esp_id}"])
        sequencia_mean.append(media_loureiro[sc][f"vazio_2_esp_{esp_id}"])

        sequencia_mean.append(media_diana[sc][f"vazio_1_esp_{esp_id}"])
        sequencia_mean.append(media_diana[sc][f"vazio_2_esp_{esp_id}"])

        sequencia_std.append(std_loureiro[sc][f"vazio_1_esp_{esp_id}"])
        sequencia_std.append(std_loureiro[sc][f"vazio_2_esp_{esp_id}"])

        sequencia_std.append(std_diana[sc][f"vazio_1_esp_{esp_id}"])
        sequencia_std.append(std_diana[sc][f"vazio_2_esp_{esp_id}"])

        sequencia_max.append(max_loureiro[sc][f"vazio_1_esp_{esp_id}"])
        sequencia_max.append(max_loureiro[sc][f"vazio_2_esp_{esp_id}"])

        sequencia_max.append(max_diana[sc][f"vazio_1_esp_{esp_id}"])
        sequencia_max.append(max_diana[sc][f"vazio_2_esp_{esp_id}"])

        # 2) COM PESSOA: percorre todas as outras posições

        # GRALHA CÓDIGO ORIGINAL
        # # o "if" apenas serve para o grupo "vazio_1" e não para "vazio_2"
        for posicao in posicoes:
            if posicao.startswith("vazio"):
                continue

            key = f"{posicao}_esp_{esp_id}"
            sequencia_mean.append(media_loureiro[sc][key])
            sequencia_mean.append(media_diana[sc][key])

            sequencia_std.append(std_loureiro[sc][key])
            sequencia_std.append(std_diana[sc][key])

            sequencia_max.append(max_loureiro[sc][key])
            sequencia_max.append(max_diana[sc][key])

        # 3) concatena e guarda
        coluna_media[name_mean] = np.concatenate(sequencia_mean)
        coluna_std[name_std] = np.concatenate(sequencia_std)
        coluna_max[name_max] = np.concatenate(sequencia_max)

for sc_label, sc in subcarriers_map.items():
    for esp_id in esps_id:
        # nome da coluna
        name_mean_af = f"Mean sc_{sc_label} esp_{esp_id}"
        name_std_af = f"Std sc_{sc_label} esp_{esp_id}"
        name_max_af = f"Max sc_{sc_label} esp_{esp_id}"

        seq_mean, seq_std, seq_max = [], [], []

        for posicao in posicoes_afinar:
            key = f"{posicao}_esp_{esp_id}"

            seq_mean.append(media_afinar[sc][key])
            seq_std.append(std_afinar[sc][key])
            seq_max.append(max_afinar[sc][key])

        coluna_media_afinar[name_mean_af] = np.concatenate(seq_mean)
        coluna_std_afinar[name_std_af] = np.concatenate(seq_std)
        coluna_max_afinar[name_max_af] = np.concatenate(seq_max)

# %%
tamanho_loureiro = (
    len(media_loureiro[1]["vazio_1_esp_1"])
    + len(media_loureiro[1]["vazio_1_esp_1"])
    + len(media_loureiro[1]["a00_esp_1"]) * 42
)
print(len(media_loureiro[1]["vazio_1_esp_1"]) + len(media_loureiro[1]["vazio_1_esp_1"]))
print(tamanho_loureiro)

tamanhos_diana = (
    len(media_diana[1]["vazio_1_esp_1"])
    + len(media_diana[1]["vazio_1_esp_1"])
    + len(media_diana[1]["a00_esp_1"]) * 42
)
print(len(media_diana[1]["vazio_1_esp_1"]) + len(media_diana[1]["vazio_1_esp_1"]))
print(tamanhos_diana)

total = tamanho_loureiro + tamanhos_diana
print(total)
print(len(coluna_media["Mean sc_1 esp_1"]))
# Out:
# 228
# 1362
# 228
# 1362
# 2724
# 2602

# %% [markdown]
# ##### Coluna target

# %%
# truncar todas as colunas numa só
# para verificar qual o tamanho do menor vetor
all_cols: dict[str, np.ndarray] = {**coluna_media, **coluna_std, **coluna_max}
min_len: int = min(len(v) for v in all_cols.values())

# trunca as colunas para o tamanho do menor vetor (min_len)
coluna_media = {k: v[:min_len] for k, v in coluna_media.items()}
coluna_std = {k: v[:min_len] for k, v in coluna_std.items()}
coluna_max = {k: v[:min_len] for k, v in coluna_max.items()}

# Gera o vetor de labels (0 = vazio, 1 = com_pessoa)
# o número de zeros é a soma dos tamanhos dos grupos "sem pessoa"
# tanto do Loureiro como da Diana
# # a subportadora 22 é escolhida arbitrariamente, pois todas têm o mesmo número de leituras
n_zero: int = sum(
    len(media_loureiro[22][f"vazio_1_esp_{esp_id}"])
    + len(media_loureiro[22][f"vazio_2_esp_{esp_id}"])
    + len(media_diana[22][f"vazio_1_esp_{esp_id}"])
    + len(media_diana[22][f"vazio_2_esp_{esp_id}"])
    for esp_id in esps_id
)

# Total de linhas (após truncar tudo para min_len)
n_total: int = min_len

# Cria vetor target: 0 para "sem pessoa", 1 para "com pessoa"
target_vector: np.ndarray = np.zeros(n_total, dtype=int)
target_vector[n_zero:] = 1  # a partir do índice n_zero, coloca 1 (com pessoa)

# %% [markdown]
# Criar Dataframe

# %%
# DataFrame
df: pd.DataFrame = pd.DataFrame({**coluna_media, **coluna_std, **coluna_max})
df["target"] = target_vector

print(df["target"].value_counts())
print(df.shape)

# descrever categorical columns
df.describe()
# Out:
# target
# 0    1453
# 1    1149
# Name: count, dtype: int64
# (2602, 613)
#        Mean sc_1 esp_1  Mean sc_1 esp_2  Mean sc_1 esp_3  Mean sc_1 esp_4  \
# count      2602.000000      2602.000000      2602.000000      2602.000000
# mean         -0.000583         0.404557         0.152552         0.012654
# std           0.104641         0.403405         0.255293         0.139052
# min          -0.400175        -0.570497        -0.574555        -0.395496
# 25%          -0.046129         0.084524        -0.051165        -0.091953
# 50%           0.010988         0.435701         0.107261         0.012549
# 75%           0.072380         0.757710         0.327998         0.118875
# max           0.349266         1.446976         0.990220         0.445587
#
#        Mean sc_2 esp_1  Mean sc_2 esp_2  Mean sc_2 esp_3  Mean sc_2 esp_4  \
# count      2602.000000      2602.000000      2602.000000      2602.000000
# mean         -0.039840         0.382138         0.271782         0.143074
# std           0.104788         0.352760         0.284158         0.179966
# min          -0.418388        -0.535822        -0.548466        -0.359255
# 25%          -0.076808         0.105242         0.041572         0.006915
# 50%          -0.023429         0.421282         0.217985         0.153197
# 75%           0.021292         0.684486         0.491005         0.282462
# max           0.242367         1.390318         1.184172         0.596477
#
#        Mean sc_3 esp_1  Mean sc_3 esp_2  ...  Max sc_49 esp_4  \
# count      2602.000000      2602.000000  ...      2602.000000
# mean         -0.085994         0.314021  ...         0.120080
# std           0.124487         0.279867  ...         0.210285
# min          -0.501252        -0.512225  ...        -0.292282
# 25%          -0.154887         0.098567  ...        -0.117806
# 50%          -0.073438         0.337405  ...         0.182285
# 75%           0.000928         0.541070  ...         0.295486
# max           0.314470         1.114364  ...         1.247278
#
#        Max sc_50 esp_1  Max sc_50 esp_2  Max sc_50 esp_3  Max sc_50 esp_4  \
# count      2602.000000      2602.000000      2602.000000      2602.000000
# mean          0.206008         0.257880         0.013223         0.117927
# std           0.219499         0.233397         0.214004         0.195951
# min          -0.502197        -0.706747        -0.925782        -0.280768
# 25%           0.113122         0.114749        -0.107835        -0.096475
# 50%           0.192989         0.266434         0.009479         0.170826
# 75%           0.274420         0.415536         0.113276         0.277777
# max           1.783707         1.578296         1.371507         1.307226
#
#        Max sc_51 esp_1  Max sc_51 esp_2  Max sc_51 esp_3  Max sc_51 esp_4  \
# count      2602.000000      2602.000000      2602.000000      2602.000000
# mean          0.162287         0.723565         0.490416         0.192911
# std           0.160581         0.441595         0.432341         0.203045
# min          -0.392018        -0.726956        -0.461716        -0.254286
# 25%           0.064177         0.392259         0.136206         0.081528
# 50%           0.173597         0.692973         0.392592         0.175004
# 75%           0.262512         1.020856         0.926901         0.246280
# max           1.091530         2.459760         1.442768         1.988634
#
#             target
# count  2602.000000
# mean      0.441583
# std       0.496671
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 613 columns]

# %% [markdown]
# #### *Machine Learning*

# %% [markdown]
# ##### Dataframe normal

# %% [markdown]
# Divisão treino/teste

# %%
# features
X: np.ndarray = df.drop(columns="target").to_numpy()

# target
y = df["target"].to_numpy()

print("X.shape =", X.shape)
print("y.shape =", y.shape)


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=200,
)

print("X_train.shape =", X_train.shape)
print("X_test.shape  =", X_test.shape)
print("y_train.shape =", y_train.shape)
print("y_test.shape  =", y_test.shape)
# Out:
# X.shape = (2602, 612)
# y.shape = (2602,)
# X_train.shape = (2081, 612)
# X_test.shape  = (521, 612)
# y_train.shape = (2081,)
# y_test.shape  = (521,)

# %% [markdown]
# Random Forest Classifier

# %%
model = RandomForestClassifier(
    min_samples_split=4,
    min_samples_leaf=4,
    max_leaf_nodes=64,
    n_estimators=150,
    random_state=200,
    max_depth=16,
    class_weight="balanced_subsample",
    criterion="entropy",
)

model = model.fit(X_train, y_train)

# pkl_path = path + "\\modelo_treinado.pkl"
# joblib.dump(model, pkl_path)
# print(f"Modelo guardado em: {pkl_path}")

# %%
pred_test = model.predict(X_test)

bal_acc = balanced_accuracy_score(y_test, pred_test)
print("Balanced accuracy:", bal_acc * 100, "%")
# Out:
# Balanced accuracy: 97.40782722825439 %

# %% [markdown]
# Confusion Matrix

# %%
confusion_matrix_test = confusion_matrix(y_test, pred_test)

# %%
sns.set_theme(font_scale=1.2)
plt.figure(figsize=(6, 5))

sns.heatmap(
    confusion_matrix_test,
    annot=True,
    fmt="d",
    cmap="Reds",
    xticklabels=["Sem pessoa", "Com pessoa"],
    yticklabels=["Sem pessoa", "Com pessoa"],
)

plt.title("Matriz de Confusão")
plt.xlabel("Previsto")
plt.ylabel("Real")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Dataframe Afinar

# %% [markdown]
# Criar Dataframe

# %%
# verificar menor tamanho das colunas
all_cols_afinar = {**coluna_media_afinar, **coluna_std_afinar, **coluna_max_afinar}
min_len_af: int = min(len(v) for v in all_cols_afinar.values())

# trunca todas as colunas ao mesmo tamanho
coluna_media_afinar = {k: v[:min_len_af] for k, v in coluna_media_afinar.items()}
coluna_std_afinar = {k: v[:min_len_af] for k, v in coluna_std_afinar.items()}
coluna_max_afinar = {k: v[:min_len_af] for k, v in coluna_max_afinar.items()}

# Do Miguel:
# # Como há apenas 4 ESPs x 1 ficheiro por classe, a divisão é simples:
# # Cada classe (com_pessoa, vazio) tem 4 séries → total 8
# # O label muda a meio

# Total de linhas após truncamento
n_total_afinar = min_len_af
n_zero_afinar = n_total_afinar // 2  # metade "sem pessoa", metade "com pessoa"

# Gera os rótulos
target_vector_afinar = np.zeros(n_total_afinar, dtype=int)
target_vector_afinar[n_zero_afinar:] = 1

# DF Afinar
df_afinar = pd.DataFrame(
    {**coluna_media_afinar, **coluna_std_afinar, **coluna_max_afinar}
)
df_afinar["label"] = target_vector_afinar

# Verifica
print(df_afinar["label"].value_counts())
print(df_afinar.shape)
display(df_afinar)
# Out:
# label
# 0    120
# 1    120
# Name: count, dtype: int64
# (240, 613)
#      Mean sc_1 esp_1  Mean sc_1 esp_2  Mean sc_1 esp_3  Mean sc_1 esp_4  \
# 0          -0.190710         0.071904         0.022125         0.065439
# 1          -0.098345         0.185991         0.032903         0.094501
# 2          -0.149652         0.170039         0.022409         0.146528
# 3          -0.138272         0.179928         0.233745         0.174710
# 4          -0.086191         0.283230         0.377084         0.132471
# ..               ...              ...              ...              ...
# 235        -0.477658         0.429618         0.376045        -0.000067
# 236        -0.505456         0.410408         0.184368        -0.015495
# 237        -0.501239         0.269922         0.162407         0.009802
# 238        -0.400639         0.331451         0.129421         0.059799
# 239        -0.380862         0.322577         0.321428         0.040678
#
#      Mean sc_2 esp_1  Mean sc_2 esp_2  Mean sc_2 esp_3  Mean sc_2 esp_4  \
# 0          -0.233436         0.228570         0.143782         0.256334
# 1          -0.104833         0.268291         0.151759         0.295333
# 2          -0.136147         0.257203         0.156954         0.357201
# 3          -0.131709         0.262334         0.361672         0.417753
# 4          -0.058909         0.334329         0.497813         0.361861
# ..               ...              ...              ...              ...
# 235        -0.547077         0.353689         0.502735         0.168371
# 236        -0.537760         0.347821         0.304637         0.139880
# 237        -0.516472         0.300919         0.302240         0.112890
# 238        -0.429826         0.353367         0.323398         0.174434
# 239        -0.394829         0.356402         0.492989         0.140799
#
#      Mean sc_3 esp_1  Mean sc_3 esp_2  ...  Max sc_49 esp_4  Max sc_50 esp_1  \
# 0          -0.236852         0.218763  ...        -0.142611         0.293978
# 1          -0.102585         0.262529  ...         0.409435         0.278356
# 2          -0.135761         0.251858  ...        -0.167230         0.866201
# 3          -0.138234         0.267656  ...        -0.174666         0.375517
# 4          -0.049737         0.316191  ...         0.186839         0.273106
# ..               ...              ...  ...              ...              ...
# 235        -0.542630         0.312371  ...         0.402859         0.117625
# 236        -0.466160         0.315063  ...         0.304968         0.208329
# 237        -0.459856         0.278649  ...         0.212531         0.371860
# 238        -0.384997         0.314087  ...         0.469916         0.136934
# 239        -0.341954         0.340516  ...        -0.104800         0.320872
#
#      Max sc_50 esp_2  Max sc_50 esp_3  Max sc_50 esp_4  Max sc_51 esp_1  \
# 0           0.203769         1.011441        -0.133929         0.077369
# 1           0.438138         0.107074         0.388137         0.258777
# 2           0.160113         0.056146        -0.148043         0.135877
# 3           0.180322         0.031075        -0.154711         0.108604
# 4           0.182142         0.009479         0.172205         0.107542
# ..               ...              ...              ...              ...
# 235         0.203769         0.260621         0.404346        -0.093529
# 236         0.196603         0.400350         0.287230        -0.062879
# 237         0.337441         0.103336         0.215535         0.000312
# 238         0.407922         0.349265         0.476180        -0.046689
# 239         0.313108         0.076806        -0.058794         0.117067
#
#      Max sc_51 esp_2  Max sc_51 esp_3  Max sc_51 esp_4  label
# 0           0.470389         0.512097         0.138535      0
# 1           0.750705         0.039971         0.163524      0
# 2           0.467569         0.713960         0.168458      0
# 3           0.501054         0.796499         0.562996      0
# 4           0.492754         0.790100         0.141898      0
# ..               ...              ...              ...    ...
# 235         0.439070         0.702203        -0.020830      1
# 236         0.678230         0.701360        -0.054708      1
# 237         0.547252         0.544942         0.116425      1
# 238         0.589505         0.442181         0.141898      1
# 239         0.555261         0.916265         0.095621      1
#
# [240 rows x 613 columns]

# %% [markdown]
# Confusion Matrix

# %%
# Garantir arrays numpy (evita ExtensionArray / typing issues)
X_afinar: np.ndarray = df_afinar.drop(columns="label").to_numpy()
y_afinar: np.ndarray = df_afinar["label"].to_numpy()

# Prever com o modelo atual
y_pred_afinar = model.predict(X_afinar)

# Índices dos erros
falsos_negativos = (y_afinar == 1) & (y_pred_afinar == 0)
falsos_positivos = (y_afinar == 0) & (y_pred_afinar == 1)

# Extrair exemplos incorretamente classificados
X_erros = X_afinar[falsos_negativos | falsos_positivos]
y_erros = y_afinar[falsos_negativos | falsos_positivos]

print(f"Total de exemplos a adicionar (FP + FN): {len(y_erros)}")

# --- Calcular a matriz de confusão ---
cm = confusion_matrix(y_afinar, y_pred_afinar)
print("Confusion Matrix (dataset2):")
print(cm)
# Out:
# Total de exemplos a adicionar (FP + FN): 111
# Confusion Matrix (dataset2):
# [[111   9]
#  [102  18]]

# %%
# Reforçar treino com os exemplos mal classificados
X_treinado_reforcado = np.vstack([X_train, X_erros])
y_treinado_reforcado = np.hstack([y_train, y_erros])

print(X_treinado_reforcado.shape, y_treinado_reforcado.shape)
display(X_treinado_reforcado.shape, y_treinado_reforcado.shape)
# Out:
# (2192, 612) (2192,)
# (2192, 612)
# (2192,)

# %% [markdown]
# Random Forest Classifier

# %%
modelo2 = RandomForestClassifier(
    min_samples_split=16,
    min_samples_leaf=4,
    max_leaf_nodes=64,
    n_estimators=150,
    random_state=200,
    max_depth=32,
    class_weight="balanced_subsample",
    criterion="entropy",
    n_jobs=-1,
)

modelo2.fit(X_treinado_reforcado, y_treinado_reforcado)

y_pred_novo = modelo2.predict(X_test)

print(
    "Balanced Accuracy do novo modelo: ",
    balanced_accuracy_score(y_test, y_pred_novo) * 100,
    "%",
)
# Out:
# Balanced Accuracy do novo modelo:  97.28030664598496 %

# %% [markdown]
# ##### Grid Search

# %%
# Grid Search
# 432 combinações
param_grid = {
    "min_samples_split": [4, 16, 32],
    "min_samples_leaf": [4, 16, 32, 64],
    "max_leaf_nodes": [4, 16, 32, 64],
    "n_estimators": [100, 150, 200],
    "max_depth": [4, 16, 32],
}

rf = RandomForestClassifier(
    random_state=200,
    class_weight="balanced_subsample",
    criterion="entropy",
)

scorer = make_scorer(balanced_accuracy_score)

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring=scorer,
    cv=5,
    n_jobs=-1,
    verbose=2,
)

# fit
grid_search.fit(X_treinado_reforcado, y_treinado_reforcado)

# Best model and parameters
print("Best balanced accuracy:", grid_search.best_score_)
print("Best params:", grid_search.best_params_)

# Predict with best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print("Test balanced accuracy:", balanced_accuracy_score(y_test, y_pred))

# %% [markdown]
# Print final (~ 50 minutos):
#  * Fitting 5 folds for each of 432 candidates, totalling 2160 fits
#  * Best balanced accuracy: 0.9039040507887066
#  * Best params: {'max_depth': 16, 'max_leaf_nodes': 64, 'min_samples_leaf': 4, 'min_samples_split': 16, 'n_estimators': 200}
# * Test balanced accuracy: 0.9663375492184703
